# %% [markdown]
# # TP1 — Aprendizaje Profundo: MLP vs CNNs en un Escenario Realista
#
# ## Overfitting, sesgo inductivo, regularización y desbalance de clases
#
# Este trabajo práctico toma como punto de partida el experimento clásico **MLP vs CNN sobre MNIST**, pero lo traslada a un escenario mucho más cercano a los problemas reales de aprendizaje automático: **pocos datos, desbalance de clases y necesidad de regularización**.
#
# En el MNIST original, con 60.000 imágenes de entrenamiento bien balanceadas, el problema es tan sencillo que muchas diferencias importantes entre modelos quedan ocultas. En cambio, si reducimos drásticamente el conjunto de entrenamiento y además introducimos un desbalance severo, aparecen fenómenos que sí son fundamentales en Deep Learning:
#
# - overfitting;
# - diferencias reales entre una arquitectura densa y una convolucional;
# - necesidad de usar regularización explícita e implícita;
# - importancia de usar métricas más ricas que la accuracy.
#
# ### Idea clave
# Este notebook no busca “ganarle a MNIST”, sino usar un problema controlado para estudiar **cómo piensan y cómo fallan los modelos**.
#
# ### Objetivos pedagógicos
# Al finalizar este trabajo práctico deberías poder:
#
# - distinguir memorizar de generalizar;
# - explicar por qué una CNN suele generalizar mejor que una MLP en imágenes;
# - entender el rol de dropout, weight decay, data augmentation y class-weighted loss;
# - interpretar correctamente accuracy, balanced accuracy y macro-F1;
# - analizar curvas de entrenamiento, matrices de confusión y errores por clase.
#
# ### Hoja de ruta
# 1. Construimos un MNIST reducido y desbalanceado.
# 2. Visualizamos el problema y cuantificamos el desbalance.
# 3. Definimos una MLP y una CNN.
# 4. Implementamos el loop de entrenamiento.
# 5. Entrenamos variantes baseline y regularizadas.
# 6. Analizamos resultados con métricas globales y por clase.
# 7. Discutimos qué nos enseñan los resultados sobre Deep Learning.

# %% [markdown]
# ## 0. Nota para Google Colab
#
# Este notebook está pensado para correr en **Google Colab**. Se recomienda activar GPU desde:
#
# **Entorno de ejecución → Cambiar tipo de entorno de ejecución → GPU**
#
# Aun así, el diseño del dataset hace que también sea razonablemente ejecutable en CPU.
#
# ### Importante
# En esta versión del TP **no está todo resuelto**. Hay secciones `TODO` que debés completar vos:
#
# - definición de la **MLP**;
# - definición de la **CNN**;
# - implementación de la **función de pérdida**;
# - implementación del **loop de entrenamiento y validación**.
#
# La idea es que el notebook te guíe, pero que la parte central del experimento la construyas vos.

# %%
# Si trabajás en un entorno limpio, descomentá esta línea:
# !pip -q install torch torchvision numpy pandas matplotlib scikit-learn

import os
import math
import copy
import time
import random
import warnings
import itertools
from typing import Dict, List, Optional

import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

import torch
import torch.nn as nn
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import datasets, transforms

from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
)

plt.style.use("seaborn-v0_8-whitegrid")
plt.rcParams.update({
    "font.size": 12,
    "figure.facecolor": "white",
    "axes.titleweight": "bold",
    "axes.labelweight": "bold",
})

warnings.filterwarnings("ignore", category=UserWarning)

print(f"PyTorch version: {torch.__version__}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Dispositivo en uso: {device.type.upper()}")
# Out:
# PyTorch version: 2.10.0+cu128
# Dispositivo en uso: CUDA

# %% [markdown]
# ## 1. Reproducibilidad científica
#
# En aprendizaje profundo, dos corridas aparentemente idénticas pueden producir resultados distintos por varios motivos:
#
# - inicialización aleatoria de los pesos,
# - orden aleatorio de los minibatches,
# - operaciones no determinísticas en GPU.
#
# Fijar semillas no garantiza identidad absoluta en todos los entornos, pero sí reduce muchísimo la variabilidad y vuelve las comparaciones más justas.
#
# ### Mensaje para llevarse
# Si querés comparar modelos, primero necesitás **controlar el experimento**.

# %%
def seed_everything(seed: int = 42) -> None:
    """Fija semillas de Python, NumPy y PyTorch."""
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

seed_everything(42)
print("Semillas fijadas correctamente.")
# Out:
# Semillas fijadas correctamente.

# %% [markdown]
# ## 2. Configuración global del experimento
#
# Vamos a construir un subset muy pequeño y desbalanceado del conjunto de entrenamiento original.
#
# ### Idea clave
# No estamos cambiando el dominio del problema. Seguimos trabajando con **MNIST**. Lo que cambia es el régimen estadístico:
#
# - menos datos;
# - clases frecuentes y clases raras;
# - mayor posibilidad de sobreajuste;
# - mayor necesidad de métricas robustas.
#
# ### Qué deberías observar
# Las clases **0 y 1** tendrán muchísimos más ejemplos que **8 y 9**. Eso vuelve al entrenamiento mucho más interesante que el MNIST estándar.

# %%
CONFIG = {
    "seed": 42,
    "data_dir": "./data",
    "batch_size": 512,
    "num_workers": 0,
    "epochs": 25,
    "learning_rate": 1e-3,
    "val_fraction": 0.20,
    "early_stopping_patience": 15,  # por ejemplo: 5
    "subset_counts": {
        0: 800,
        1: 800,
        2: 400,
        3: 400,
        4: 100,
        5: 100,
        6: 100,
        7: 100,
        8: 50,
        9: 50,
    },
}

total_subset = sum(CONFIG["subset_counts"].values())
print(f"Tamaño total del dataset reducido (train + val): {total_subset}")
pd.Series(CONFIG["subset_counts"]).rename("cantidad")
# Out:
# Tamaño total del dataset reducido (train + val): 2900
# 0    800
# 1    800
# 2    400
# 3    400
# 4    100
# 5    100
# 6    100
# 7    100
# 8     50
# 9     50
# Name: cantidad, dtype: int64

# %% [markdown]
# ## 3. Un repaso conceptual antes del código
#
# ### 3.1 Capacidad del modelo y overfitting
# Una red con alta capacidad puede representar funciones muy complejas. Si el conjunto de entrenamiento es pequeño, esa capacidad puede usarse para memorizar ejemplos particulares en lugar de extraer regularidades que generalicen.
#
# - **Train loss muy baja** no implica buen modelo.
# - El indicador importante es el comportamiento sobre **validación** y **test**.
#
# ### 3.2 Sesgo inductivo
# El sesgo inductivo es el conjunto de suposiciones que hace el modelo para extrapolar a ejemplos no vistos.
#
# - Una **MLP** toma la imagen y la aplana en un vector. Trata a cada píxel como una entrada genérica, sin privilegiar la estructura 2D.
# - Una **CNN** usa filtros locales y comparte pesos. Asume que la estructura local importa y que ciertos patrones pueden reaparecer en distintas posiciones.
#
# ### 3.3 Regularización
# Vamos a usar dos tipos de regularización:
#
# - **Explícita**: dropout, weight decay, class-weighted loss.
# - **Implícita / por datos**: data augmentation.
#
# ### 3.4 Métricas y desbalance
# En datasets desbalanceados la accuracy puede ser engañosa. Por eso usamos además:
#
# - **Balanced Accuracy**: promedio del recall por clase.
# - **Macro-F1**: promedio no ponderado del F1 de cada clase.
#
# ### Error conceptual frecuente
# Pensar que “si la accuracy es alta, el modelo está bien”. En problemas desbalanceados eso puede ser completamente falso.

# %% [markdown]
# ## 4. Construcción del dataset reducido y desbalanceado
#
# Vamos a:
#
# - descargar MNIST original,
# - seleccionar una cantidad fija por clase,
# - partir ese subset en entrenamiento y validación de forma estratificada,
# - dejar el conjunto de test intacto.

# %%
# Transformaciones base
eval_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)),
])

# Data augmentation suave para entrenamiento
train_transform_aug = transforms.Compose([
    transforms.RandomAffine(degrees=15, translate=(0.08, 0.08), scale=(0.95, 1.05)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,)),
])

mnist_train_raw = datasets.MNIST(root=CONFIG["data_dir"], train=True, download=True)
mnist_test = datasets.MNIST(root=CONFIG["data_dir"], train=False, download=True, transform=eval_transform)

print(f"MNIST original - Train: {len(mnist_train_raw)} | Test: {len(mnist_test)}")
# Out:
# MNIST original - Train: 60000 | Test: 10000

# %%
def build_reduced_indices(targets: np.ndarray, subset_counts: Dict[int, int], seed: int = 42) -> np.ndarray:
    rng = np.random.default_rng(seed)
    final_indices = []

    for cls, count in subset_counts.items():
        cls_indices = np.where(targets == cls)[0]
        rng.shuffle(cls_indices)

        if count > len(cls_indices):
            raise ValueError(f"La clase {cls} pidió {count} ejemplos, pero sólo hay {len(cls_indices)}.")
        final_indices.extend(cls_indices[:count].tolist())

    final_indices = np.array(final_indices)
    rng.shuffle(final_indices)
    return final_indices


def stratified_train_val_split(
    indices: np.ndarray,
    targets: np.ndarray,
    val_fraction: float = 0.20,
    seed: int = 42,
):
    rng = np.random.default_rng(seed)
    train_idx, val_idx = [], []

    for cls in sorted(np.unique(targets[indices])):
        cls_indices = indices[targets[indices] == cls].copy()
        rng.shuffle(cls_indices)

        n_val = max(1, int(round(len(cls_indices) * val_fraction)))
        val_idx.extend(cls_indices[:n_val].tolist())
        train_idx.extend(cls_indices[n_val:].tolist())

    train_idx = np.array(train_idx)
    val_idx = np.array(val_idx)
    rng.shuffle(train_idx)
    rng.shuffle(val_idx)
    return train_idx, val_idx


targets_np = mnist_train_raw.targets.cpu().numpy()
reduced_indices = build_reduced_indices(targets_np, CONFIG["subset_counts"], CONFIG["seed"])
train_indices, val_indices = stratified_train_val_split(
    reduced_indices,
    targets_np,
    val_fraction=CONFIG["val_fraction"],
    seed=CONFIG["seed"],
)

print(f"Nuestro setup - Train: {len(train_indices)} | Val: {len(val_indices)} | Test: {len(mnist_test)}")
# Out:
# Nuestro setup - Train: 2320 | Val: 580 | Test: 10000

# %%
class TensorMNISTDataset(Dataset):
    """Dataset auxiliar para aplicar transforms a subconjuntos indexados de MNIST."""
    def __init__(self, images: torch.Tensor, labels: torch.Tensor, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        image = self.images[idx]
        label = int(self.labels[idx])
        pil_img = TF.to_pil_image(image)

        if self.transform is not None:
            x = self.transform(pil_img)
        else:
            x = TF.to_tensor(pil_img)
        return x, label


all_images = mnist_train_raw.data
all_labels = mnist_train_raw.targets

train_images = all_images[train_indices]
train_labels = all_labels[train_indices]
val_images = all_images[val_indices]
val_labels = all_labels[val_indices]

train_dataset_plain = TensorMNISTDataset(train_images, train_labels, transform=eval_transform)
train_dataset_aug = TensorMNISTDataset(train_images, train_labels, transform=train_transform_aug)
val_dataset = TensorMNISTDataset(val_images, val_labels, transform=eval_transform)

print("Datasets preparados.")
# Out:
# Datasets preparados.

# %% [markdown]
# ## 5. Análisis exploratorio visual
#
# Antes de entrenar una red, conviene entender bien qué distribución de datos verá el modelo.
#
# ### Qué mirar
# - la severidad del desbalance;
# - cuántos ejemplos realmente quedan por clase;
# - cómo lucen las imágenes de cada clase;
# - qué tan fuerte es el augmentation aplicado.

# %%
def count_labels(labels: torch.Tensor) -> Dict[int, int]:
    unique, counts = torch.unique(labels, return_counts=True)
    return {int(k): int(v) for k, v in zip(unique, counts)}

train_counts = count_labels(train_labels)
val_counts = count_labels(val_labels)

classes = list(range(10))
train_hist = [train_counts.get(c, 0) for c in classes]
val_hist = [val_counts.get(c, 0) for c in classes]

fig, ax = plt.subplots(figsize=(11, 5))
x = np.arange(len(classes))
width = 0.36

ax.bar(x - width/2, train_hist, width=width, label="Entrenamiento", edgecolor="black", alpha=0.9)
ax.bar(x + width/2, val_hist, width=width, label="Validación", edgecolor="black", alpha=0.9)

ax.set_xticks(classes)
ax.set_xlabel("Clase")
ax.set_ylabel("Cantidad de imágenes")
ax.set_title("Distribución de clases en el subset reducido")
ax.legend()
plt.tight_layout()
plt.show()

ratio_major_minor = train_counts[0] / train_counts[9]
print(f"Razón entre la clase mayoritaria 0 y la minoritaria 9 en train: {ratio_major_minor:.1f} a 1")
# Out:
# Razón entre la clase mayoritaria 0 y la minoritaria 9 en train: 16.0 a 1

# %% [markdown]
# ### Interpretación
# La red verá muchas más imágenes de algunas clases que de otras. Eso crea un incentivo estadístico a favorecer a las clases frecuentes.
#
# ### Mensaje para llevarse
# Si no hacemos nada, el modelo puede volverse “perezoso”: aprende muy bien las clases comunes y rinde mal en las raras.

# %%
def show_examples_per_class(images: torch.Tensor, labels: torch.Tensor, n: int = 6):
    fig, axes = plt.subplots(10, n, figsize=(1.5 * n, 14))
    fig.suptitle("Ejemplos reales del subset reducido", fontsize=16, fontweight="bold", y=0.995)

    for cls in range(10):
        cls_indices = torch.where(labels == cls)[0][:n]
        for j in range(n):
            ax = axes[cls, j]
            if j < len(cls_indices):
                idx = cls_indices[j]
                ax.imshow(images[idx], cmap="gray")
            ax.axis("off")
            if j == 0:
                ax.text(-0.35, 0.5, f"Clase {cls}", va="center", ha="right",
                        transform=ax.transAxes, fontsize=11, fontweight="bold")
    plt.tight_layout()
    plt.show()

show_examples_per_class(train_images, train_labels, n=6)

# %%
def show_augmentation_examples(dataset_plain: Dataset, dataset_aug: Dataset, n: int = 6):
    fig, axes = plt.subplots(2, n, figsize=(1.7 * n, 4))
    fig.suptitle("Ejemplo de imágenes originales vs. aumentadas", fontsize=15, fontweight="bold", y=1.03)

    for j in range(n):
        x_plain, y = dataset_plain[j]
        x_aug, _ = dataset_aug[j]

        axes[0, j].imshow(x_plain.squeeze().numpy(), cmap="gray")
        axes[0, j].set_title(f"Orig. ({y})", fontsize=10)
        axes[0, j].axis("off")

        axes[1, j].imshow(x_aug.squeeze().numpy(), cmap="gray")
        axes[1, j].set_title("Aug", fontsize=10)
        axes[1, j].axis("off")

    axes[0, 0].text(-0.55, 0.5, "Original", va="center", ha="right",
                    transform=axes[0, 0].transAxes, fontweight="bold")
    axes[1, 0].text(-0.55, 0.5, "Aumentada", va="center", ha="right",
                    transform=axes[1, 0].transAxes, fontweight="bold")
    plt.tight_layout()
    plt.show()

show_augmentation_examples(train_dataset_plain, train_dataset_aug, n=6)

# %% [markdown]
# ### Idea clave
# El augmentation no inventa clases nuevas, pero sí vuelve el entrenamiento más exigente. Obliga a la red a aprender representaciones más estables ante pequeñas transformaciones.
#
# ### Error conceptual frecuente
# Pensar que augmentation “mejora” la validación porque sí. En realidad, mejora la generalización porque hace más difícil el entrenamiento y desalienta la memorización exacta.

# %% [markdown]
# ## 6. Cómo vamos a tratar el desbalance
#
# En este notebook usaremos principalmente **class-weighted loss**, es decir, una función de pérdida que penaliza más los errores sobre clases minoritarias.
#
# También dejamos implementado un `WeightedRandomSampler` como extensión opcional.
#
# Si $n_c$ es la cantidad de ejemplos de la clase \(c\), definimos un peso inversamente proporcional a su frecuencia:
#
# $$
# w_c = \frac{N}{K\, n_c}
# $$
#
# donde:
#
# - $N$ es el total de ejemplos,
# - $K$ es el número de clases.
#
# Así, las clases poco frecuentes reciben mayor peso.

# %%
def compute_class_weights(labels: torch.Tensor, num_classes: int = 10) -> torch.Tensor:
    counts = torch.bincount(labels, minlength=num_classes).float()
    weights = counts.sum() / (num_classes * counts)
    return weights

class_weights = compute_class_weights(train_labels)

weights_df = pd.DataFrame({
    "clase": list(range(10)),
    "cantidad_train": [train_counts[c] for c in range(10)],
    "peso_loss": class_weights.numpy(),
})
weights_df
# Out:
#    clase  cantidad_train  peso_loss
# 0      0             640     0.3625
# 1      1             640     0.3625
# 2      2             320     0.7250
# 3      3             320     0.7250
# 4      4              80     2.9000
# 5      5              80     2.9000
# 6      6              80     2.9000
# 7      7              80     2.9000
# 8      8              40     5.8000
# 9      9              40     5.8000

# %%
fig, ax1 = plt.subplots(figsize=(10, 4))
ax2 = ax1.twinx()

ax1.bar(weights_df["clase"], weights_df["cantidad_train"], alpha=0.75, edgecolor="black", label="Cantidad train")
ax2.plot(weights_df["clase"], weights_df["peso_loss"], marker="o", linewidth=2, label="Peso en la loss")

ax1.set_xlabel("Clase")
ax1.set_ylabel("Cantidad de ejemplos")
ax2.set_ylabel("Peso en la loss")
ax1.set_title("Frecuencia por clase y peso asignado en la función de pérdida")
plt.tight_layout()
plt.show()

# %%
def make_weighted_sampler(labels: torch.Tensor) -> WeightedRandomSampler:
    class_counts = torch.bincount(labels)
    inv_freq = 1.0 / class_counts.float()
    sample_weights = inv_freq[labels]
    return WeightedRandomSampler(weights=sample_weights, num_samples=len(labels), replacement=True)

weighted_sampler = make_weighted_sampler(train_labels)
print("WeightedRandomSampler preparado (extensión opcional).")
# Out:
# WeightedRandomSampler preparado (extensión opcional).

# %% [markdown]
# ## 7. DataLoaders
#
# Creamos una función flexible para construir `DataLoaders` según cada experimento.
#
# ### Decisión metodológica
# En los experimentos principales:
#
# - usaremos augmentation sólo cuando corresponda;
# - no usaremos `weighted_sampling` en simultáneo con `class-weighted loss` para no mezclar demasiados efectos a la vez.
#
# Eso permite que el análisis sea más limpio.

# %%
def make_loaders(
    batch_size: int = 128,
    augmentation: bool = False,
    weighted_sampling: bool = False,
    num_workers: int = 2,
):
    train_ds = train_dataset_aug if augmentation else train_dataset_plain

    if weighted_sampling:
        sampler = make_weighted_sampler(train_labels)
        train_loader = DataLoader(
            train_ds,
            batch_size=batch_size,
            sampler=sampler,
            num_workers=num_workers,
            pin_memory=torch.cuda.is_available(),
        )
    else:
        train_loader = DataLoader(
            train_ds,
            batch_size=batch_size,
            shuffle=True,
            num_workers=num_workers,
            pin_memory=torch.cuda.is_available(),
        )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=torch.cuda.is_available(),
    )

    test_loader = DataLoader(
        mnist_test,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=torch.cuda.is_available(),
    )
    return train_loader, val_loader, test_loader

# %% [markdown]
# ## 8. Modelos: una MLP y una CNN
#
# Vamos a comparar dos familias de modelos:
#
# - **MLP**: aplana la imagen y trabaja sobre un vector de 784 entradas.
# - **CNN**: usa convoluciones y pooling para explotar la estructura espacial.
#
# ### Idea clave
# La pregunta no es sólo cuál rinde mejor, sino **por qué**.
#
# ## TODO 1 — Implementar las arquitecturas
# Completá las clases `MLPClassifier` y `SimpleCNN`.
#
# ### Sugerencias mínimas
# - **MLP**: dos capas ocultas, activación `ReLU`, dropout opcional.
# - **CNN**: al menos dos bloques convolucionales con `Conv2d + ReLU + MaxPool2d`, seguidos por un clasificador final.
# - Ambas deben devolver **logits** de tamaño `(batch_size, 10)`.
#
# ### Pista
# No apliques `softmax` dentro de `forward` si vas a usar `CrossEntropyLoss`.

# %%
class MLPClassifier(nn.Module):
    """Perceptrón multicapa para imágenes 28x28."""
    def __init__(self, input_size=28*28, hidden_dims=(256, 128), dropout=0.0, num_classes=10):
        super().__init__()

        self.flatten = nn.Flatten()

        layers = []
        previous_layer = input_size

        for layer in hidden_dims:
            layers.append(nn.Linear(previous_layer, layer))     # Capa Fully Connected
            layers.append(nn.ReLU())                            # Función de activación
            if dropout > 0:
                layers.append(nn.Dropout(p=dropout))
            previous_layer = layer
        
        layers.append(nn.Linear(previous_layer, num_classes))   # Capa de salida

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        x = self.flatten(x)
        return self.network(x)

# %%
def conv_output_size(input_size, kernel_size, stride=1, padding=0, dilation=1):
    return math.floor(
        (input_size + 2 * padding - dilation * (kernel_size - 1) - 1)
        / stride + 1
    )

# %%
class SimpleCNN(nn.Module):
    """CNN pequeña para estudiar sesgo inductivo en MNIST."""
    def __init__(
            self, 
            base_channels: list[int] = [6, 16], kernel_sizes: list[int] = [3, 3], 
            paddings: list[int] = [1, 0], hidden_layers = [512, 256], 
            dropout=0.0, num_classes=10, batch_norm: bool = False
        ):
        super().__init__()
        if len(base_channels) != len(kernel_sizes) != len(paddings):
            raise ValueError('Tamaños inválidos de parámetros para capas Conv.')
        
        previous_layer = self._init_conv_layers(base_channels, kernel_sizes, paddings, batch_norm)
        
        self._init_fc_layers(hidden_layers, previous_layer, dropout, num_classes)

    def _init_conv_layers(self, base_channels: list[int], kernel_sizes: list[int], paddings: list[int], batch_norm: bool) -> int:
        conv_layers = []
        previous_channel = 1
        last_channel_size = 28

        for channel, kernel_size, padding in zip(base_channels, kernel_sizes, paddings):
            conv_layers.append(nn.Conv2d(previous_channel, channel, kernel_size=kernel_size, padding=padding))
            if batch_norm:
                conv_layers.append(nn.BatchNorm2d(channel))
            conv_layers.append(nn.ReLU())
            conv_layers.append(nn.MaxPool2d(kernel_size=2, stride=2))
            last_channel_size = math.floor(conv_output_size(input_size=last_channel_size, kernel_size=kernel_size, padding=padding) / 2)
            previous_channel = channel
        
        self.convolutions = nn.Sequential(*conv_layers)
        return last_channel_size * last_channel_size * previous_channel

    def _init_fc_layers(self, hidden_layers: list[int], previous_layer: int, dropout: float, num_classes:int):
        fc_layers = [nn.Flatten()]

        for layer in hidden_layers:
            fc_layers.append(nn.Linear(previous_layer, layer))     # Capa Fully Connected
            fc_layers.append(nn.ReLU())                            # Función de activación
            if dropout > 0:
                fc_layers.append(nn.Dropout(p=dropout))
            previous_layer = layer

        fc_layers.append(nn.Linear(previous_layer, num_classes))   # Capa de salida
        self.classifier = nn.Sequential(*fc_layers)

    def forward(self, x):
        x = self.convolutions(x)
        return self.classifier(x)

# %%
print(SimpleCNN())
# Out:
# SimpleCNN(
#   (convolutions): Sequential(
#     (0): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=576, out_features=512, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=512, out_features=256, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
def count_parameters(model: nn.Module) -> int:
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
# Ejecutá esta celda recién después de completar las arquitecturas.
try:
    param_df = pd.DataFrame({
        "modelo": ["MLP", "CNN"],
        "parámetros": [count_parameters(MLPClassifier()), count_parameters(SimpleCNN())],
    })
    display(param_df)

    fig, ax = plt.subplots(figsize=(7, 4))
    bars = ax.bar(param_df["modelo"], param_df["parámetros"], edgecolor="black", alpha=0.85)
    ax.set_ylabel("Cantidad de parámetros")
    ax.set_title("Comparación de complejidad parametrizada")
    for bar, value in zip(bars, param_df["parámetros"]):
        ax.text(bar.get_x() + bar.get_width()/2, value, f"{value:,}", ha="center", va="bottom")
    plt.tight_layout()
    plt.show()
except NotImplementedError:
    print("Completá primero las arquitecturas para comparar parámetros.")
# Out:
#   modelo  parámetros
# 0    MLP      235146
# 1    CNN      430262

# %%
def plot_mlp_vs_cnn_schema():
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))

    # Esquema MLP
    ax = axes[0]
    ax.set_title("MLP: entrada aplanada")
    ax.add_patch(Rectangle((0.05, 0.20), 0.22, 0.60, fill=False, linewidth=2))
    ax.text(0.16, 0.50, "Imagen\n28x28", ha="center", va="center", fontsize=12)
    ax.annotate("", xy=(0.45, 0.50), xytext=(0.28, 0.50), arrowprops=dict(arrowstyle="->", lw=2))
    ax.text(0.365, 0.60, "flatten", ha="center", fontsize=11)
    for y in np.linspace(0.20, 0.80, 6):
        ax.plot([0.55, 0.55], [y, y], marker="o")
    for y in np.linspace(0.15, 0.85, 4):
        ax.plot([0.78, 0.78], [y, y], marker="o")
    for y1 in np.linspace(0.20, 0.80, 6):
        for y2 in np.linspace(0.15, 0.85, 4):
            ax.plot([0.55, 0.78], [y1, y2], alpha=0.25, linewidth=0.8)
    ax.text(0.66, 0.93, "Capas densas", ha="center", fontsize=11)
    ax.axis("off")

    # Esquema CNN
    ax = axes[1]
    ax.set_title("CNN: filtros locales y jerarquía espacial")
    ax.add_patch(Rectangle((0.05, 0.20), 0.22, 0.60, fill=False, linewidth=2))
    ax.text(0.16, 0.50, "Imagen\n28x28", ha="center", va="center", fontsize=12)
    ax.add_patch(Rectangle((0.11, 0.42), 0.07, 0.14, fill=False, linewidth=2, edgecolor="tab:red"))
    ax.annotate("", xy=(0.42, 0.50), xytext=(0.27, 0.50), arrowprops=dict(arrowstyle="->", lw=2))
    ax.add_patch(Rectangle((0.44, 0.28), 0.16, 0.44, fill=False, linewidth=2))
    ax.text(0.52, 0.50, "Mapas de\nactivación", ha="center", va="center")
    ax.annotate("", xy=(0.75, 0.50), xytext=(0.60, 0.50), arrowprops=dict(arrowstyle="->", lw=2))
    ax.add_patch(Rectangle((0.78, 0.35), 0.12, 0.30, fill=False, linewidth=2))
    ax.text(0.84, 0.50, "Clasif.", ha="center", va="center")
    ax.text(0.52, 0.88, "Convoluciones + pooling", ha="center", fontsize=11)
    ax.axis("off")

    fig.suptitle("Esquema conceptual: por qué una CNN ve distinto que una MLP", fontsize=15, fontweight="bold")
    plt.tight_layout()
    plt.show()

plot_mlp_vs_cnn_schema()

# %% [markdown]
# ### Interpretación
# Aunque una CNN pueda tener más parámetros, su estructura está mucho mejor alineada con la geometría del problema.
#
# ### Error conceptual frecuente
# Pensar que “más parámetros = necesariamente más overfitting”. La arquitectura importa. El sesgo inductivo también controla cómo se usa esa capacidad.

# %% [markdown]
# ## 9. Funciones de evaluación
#
# Estas funciones sí las dejamos implementadas porque no forman parte del núcleo del ejercicio. Nos servirán para analizar los modelos una vez entrenados.
#
# Vamos a registrar:
#
# - loss de entrenamiento y validación,
# - accuracy,
# - balanced accuracy,
# - macro-F1.
#
# Además, vamos a guardar el mejor modelo según la **macro-F1 de validación**, porque en presencia de desbalance esa métrica resume mejor el rendimiento por clase.

# %%
@torch.no_grad()
def collect_predictions(model: nn.Module, loader: DataLoader, device: torch.device):
    model.eval()
    all_logits, all_targets = [], []

    for x, y in loader:
        x = x.to(device)
        logits = model(x)
        all_logits.append(logits.cpu())
        all_targets.append(y.cpu())

    all_logits = torch.cat(all_logits, dim=0)
    all_targets = torch.cat(all_targets, dim=0)
    preds = all_logits.argmax(dim=1)
    return preds.numpy(), all_targets.numpy()


def compute_metrics(y_true, y_pred) -> Dict[str, float]:
    return {
        "accuracy": accuracy_score(y_true, y_pred),
        "balanced_accuracy": balanced_accuracy_score(y_true, y_pred),
        "macro_f1": f1_score(y_true, y_pred, average="macro"),
    }

# %% [markdown]
# ## 10. TODO 2 — Implementar el loop de entrenamiento
#
# Ahora toca completar la parte más importante del TP.
#
# Debés implementar:
#
# 1. `run_epoch`: una época de entrenamiento o validación.
# 2. `train_model`: el entrenamiento completo a lo largo de varias épocas.
#
# ### Qué debería hacer `run_epoch`
# - cambiar entre modo `train()` y `eval()`;
# - recorrer el `loader`;
# - mover tensores a `device`;
# - hacer forward;
# - calcular la loss;
# - si hay optimizador, hacer:
#   - `optimizer.zero_grad()`
#   - `loss.backward()`
#   - `optimizer.step()`
# - acumular la pérdida promedio.
#
# ### Qué debería hacer `train_model`
# - construir la `criterion`;
# - construir el optimizador (`AdamW`);
# - llamar a `run_epoch` en train y val;
# - calcular métricas;
# - guardar el mejor estado según `val_macro_f1`;
# - devolver:
#   - modelo,
#   - historial,
#   - tiempo de ejecución.
#
# ### Pistas
# - Si querés usar pérdida ponderada por clase, usá `nn.CrossEntropyLoss(weight=weights)`.
# - Si no querés ponderar clases, usá simplemente `nn.CrossEntropyLoss()`.
# - `CrossEntropyLoss` espera **logits**, no probabilidades.

# %%
def run_epoch(model: nn.Module, loader: DataLoader, criterion, optimizer=None, device=device):
    """Ejecuta una época completa de train o val y devuelve la loss promedio."""
    if optimizer:
        model.train()
    else:
        model.eval()
    
    total_loss = 0.0
    total = 0

    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)

        if optimizer:
            predictions = model(images)
        else:
            with torch.no_grad():
                predictions = model(images)
            
        loss = criterion(predictions, labels)

        if optimizer:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        total_loss += loss.item() * images.size(0)
        total += labels.size(0)
    
    return total_loss / total

# %%
def train_model(
    model: nn.Module,
    train_loader: DataLoader,
    val_loader: DataLoader,
    epochs: int,
    lr: float,
    weight_decay: float = 0.0,
    class_weighted_loss: bool = False,
    early_stopping_patience: Optional[int] = None,
    device: torch.device = device,
    model_name: str = 'Modelo',
    verbose: bool = False,
):
    """Entrena un modelo, guarda el mejor estado y devuelve history."""

    model = model.to(device)

    weights = None
    if class_weighted_loss:
        weights = compute_class_weights(train_labels).to(device)

    criterion = nn.CrossEntropyLoss(weight=weights)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    history = {
        'train_loss': [],
        'train_accuracy': [],
        'train_bal_acc': [],
        'train_macro_f1': [],
        'val_loss': [],
        'val_accuracy': [],
        'val_bal_acc': [],
        'val_macro_f1': [],
    }

    best_macro_f1 = 0.0
    best_model = None

    patience_counter = 0

    if verbose:
        print(f"\n{'='*60}")
        print(f" Entrenando: {model_name}")
        print(f" Parámetros: {count_parameters(model):,}")
        print(f" Épocas: {epochs} | LR: {lr} | Weight Decay: {weight_decay}")
        print(f"{'='*60}")
    
    start_time = time.time()

    for epoch in range(1, epochs + 1):
        train_loss = run_epoch(
            model=model, loader=train_loader, criterion=criterion, optimizer=optimizer, device=device
        )
        val_loss = run_epoch(
            model=model, loader=val_loader, criterion=criterion, device=device
        )

        train_pred, train_true = collect_predictions(model, train_loader, device)
        val_pred, val_true = collect_predictions(model, val_loader, device)

        train_metrics = compute_metrics(train_true, train_pred)
        val_metrics = compute_metrics(val_true, val_pred)
        train_macro_f1 = train_metrics['macro_f1']
        train_acc = train_metrics['accuracy']
        train_bal_acc = train_metrics['balanced_accuracy']
        val_macro_f1 = val_metrics['macro_f1']
        val_acc = val_metrics['accuracy']
        val_bal_acc = val_metrics['balanced_accuracy']

        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_accuracy'].append(train_acc)
        history['val_accuracy'].append(val_acc)
        history['train_bal_acc'].append(train_bal_acc)
        history['val_bal_acc'].append(val_bal_acc)
        history['train_macro_f1'].append(train_macro_f1)
        history['val_macro_f1'].append(val_macro_f1)
        

        if val_macro_f1 > best_macro_f1:
            best_model = copy.deepcopy(model.state_dict())
            best_macro_f1 = val_macro_f1
            patience_counter = 0
        else:
            patience_counter += 1

        if verbose and (epoch % 5 == 0 or epoch == 1):
            print(f"  Época {epoch:3d}/{epochs}  |  "
                  f"Train Loss: {train_loss:.4f}  Macro-F1: {train_macro_f1 * 100:.2f}%  |  "
                  f"Val Loss: {val_loss:.4f}  Macro-F1: {val_macro_f1 * 100:.2f}%")    

        if early_stopping_patience is not None and patience_counter >= early_stopping_patience:
            if verbose:
                print(f"Entrenamiento detenido en la época {epoch}")
            break

    elapsed = time.time() - start_time
    model.load_state_dict(best_model)
    return model, history, elapsed

# %% [markdown]
# ## 11. Diseño experimental
#
# Vamos a comparar cuatro escenarios principales:
#
# 1. **MLP baseline**
#    Control simple: alta propensión a memorizar.
#
# 2. **MLP regularizada**
#    Dropout + weight decay + class-weighted loss.
#
# 3. **CNN baseline**
#    Muestra el poder del sesgo inductivo convolucional.
#
# 4. **CNN regularizada + augmentation**
#    Agrega regularización explícita e implícita.
#
# ### Decisión importante
# No buscamos “la mejor arquitectura posible”, sino un conjunto de comparaciones que enseñe algo claro.

# %%
EXPERIMENTS = [
    {"name": "MLP_Baseline", "type": "mlp", "dropout": 0.0, "weight_decay": 0.0,   "augmentation": False, "class_weighted_loss": False, "weighted_sampling": False},
    {"name": "MLP_Regularizada", "type": "mlp", "dropout": 0.4, "weight_decay": 1e-4, "augmentation": False, "class_weighted_loss": True,  "weighted_sampling": False},
    {"name": "CNN_Baseline", "type": "cnn", "dropout": 0.0, "weight_decay": 0.0,   "augmentation": False, "class_weighted_loss": False, "weighted_sampling": False},
    {"name": "CNN_Regularizada_Aug", "type": "cnn", "dropout": 0.3, "weight_decay": 1e-4, "augmentation": True,  "class_weighted_loss": True,  "weighted_sampling": False},
]

# %%
def build_model(model_type: str, dropout: float):
    if model_type == 'mlp':
        return MLPClassifier(dropout=dropout)
    elif model_type == 'cnn':
        return SimpleCNN(dropout=dropout)
    else:
        raise ValueError('Modelo desconocido.')

# %% [markdown]
# ## 12. Entrenamiento comparativo
#
# Esta es la celda más costosa del notebook. En GPU debería correr sin problemas.
#
# Si querés una versión más rápida para probar, podés bajar `epochs` a 8 o 10.
#
# ### Qué mirar mientras corre
# - qué tan rápido baja la loss;
# - si hay señales de sobreajuste;
# - cómo cambia la validación al usar regularización;
# - si el modelo “más inteligente” es realmente el que generaliza mejor.

# %%
results = []
trained_models = {}
histories = {}

for exp in EXPERIMENTS:
    print(f"\n{'='*70}")
    print(f"🚀 Ejecutando experimento: {exp['name']}")
    print(f"{'='*70}")

    train_loader, val_loader, test_loader = make_loaders(
        batch_size=CONFIG["batch_size"],
        augmentation=exp["augmentation"],
        weighted_sampling=exp["weighted_sampling"],
        num_workers=CONFIG["num_workers"],
    )

    model = build_model(exp["type"], exp["dropout"])

    model, history, elapsed = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        epochs=CONFIG["epochs"],
        lr=CONFIG["learning_rate"],
        weight_decay=exp["weight_decay"],
        class_weighted_loss=exp["class_weighted_loss"],
        early_stopping_patience=CONFIG["early_stopping_patience"],
        device=device,
        model_name=exp['name']
    )

    val_preds, val_true = collect_predictions(model, val_loader, device)
    test_preds, test_true = collect_predictions(model, test_loader, device)

    val_metrics = compute_metrics(val_true, val_preds)
    test_metrics = compute_metrics(test_true, test_preds)

    trained_models[exp["name"]] = {
        "model": model,
        "val_preds": val_preds,
        "val_true": val_true,
        "test_preds": test_preds,
        "test_true": test_true,
    }
    histories[exp["name"]] = history

    results.append({
        "Experimento": exp["name"].replace("_", " "),
        "Modelo": exp["type"].upper(),
        "Parámetros": count_parameters(model),
        "Augmentation": exp["augmentation"],
        "ClassWeightedLoss": exp["class_weighted_loss"],
        "Val Accuracy": val_metrics["accuracy"],
        "Val Balanced Acc": val_metrics["balanced_accuracy"],
        "Val Macro-F1": val_metrics["macro_f1"],
        "Test Accuracy": test_metrics["accuracy"],
        "Test Balanced Acc": test_metrics["balanced_accuracy"],
        "Test Macro-F1": test_metrics["macro_f1"],
        "Tiempo (s)": elapsed,
    })
# Out:
# ======================================================================
# 🚀 Ejecutando experimento: MLP_Baseline
# ======================================================================
#
# ======================================================================
# 🚀 Ejecutando experimento: MLP_Regularizada
# ======================================================================
#
# ======================================================================
# 🚀 Ejecutando experimento: CNN_Baseline
# ======================================================================
#
# ======================================================================
# 🚀 Ejecutando experimento: CNN_Regularizada_Aug
# ======================================================================

# %% [markdown]
# ## 13. Síntesis cuantitativa de resultados
#
# Ahora reunimos todas las métricas en una sola tabla.
#
# ### Idea clave
# Una tabla ordenada no reemplaza el análisis, pero ayuda a ver rápidamente la jerarquía general entre modelos.

# %%
results_df = pd.DataFrame(results).sort_values(
    by=["Test Macro-F1", "Test Balanced Acc", "Test Accuracy"],
    ascending=False
).reset_index(drop=True)

display(
    results_df.style.format({
        "Parámetros": "{:,}",
        "Val Accuracy": "{:.2%}",
        "Val Balanced Acc": "{:.2%}",
        "Val Macro-F1": "{:.2%}",
        "Test Accuracy": "{:.2%}",
        "Test Balanced Acc": "{:.2%}",
        "Test Macro-F1": "{:.2%}",
        "Tiempo (s)": "{:.1f}",
    }).background_gradient(subset=["Test Macro-F1"], cmap="Greens")
)
# Out:
# <style type="text/css">
# #T_d5129_row0_col10 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_d5129_row1_col10 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_d5129_row2_col10 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_d5129_row3_col10 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_d5129">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5129_level0_col0" class="col_heading level0 col0" >Experimento</th>
#       <th id="T_d5129_level0_col1" class="col_heading level0 col1" >Modelo</th>
#       <th id="T_d5129_level0_col2" class="col_heading level0 col2" >Parámetros</th>
#       <th id="T_d5129_level0_col3" class="col_heading level0 col3" >Augmentation</th>
#       <th id="T_d5129_level0_col4" class="col_heading level0 col4" >ClassWeightedLoss</th>
#       <th id="T_d5129_level0_col5" class="col_heading level0 col5" >Val Accuracy</th>
#       <th id="T_d5129_level0_col6" class="col_heading level0 col6" >Val Balanced Acc</th>
#       <th id="T_d5129_level0_col7" class="col_heading level0 col7" >Val Macro-F1</th>
#       <th id="T_d5129_level0_col8" class="col_heading level0 col8" >Test Accuracy</th>
#       <th id="T_d5129_level0_col9" class="col_heading level0 col9" >Test Balanced Acc</th>
#       <th id="T_d5129_level0_col10" class="col_heading level0 col10" >Test Macro-F1</th>
#       <th id="T_d5129_level0_col11" class="col_heading level0 col11" >Tiempo (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5129_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5129_row0_col0" class="data row0 col0" >CNN Regularizada Aug</td>
#       <td id="T_d5129_row0_col1" class="data row0 col1" >CNN</td>
#       <td id="T_d5129_row0_col2" class="data row0 col2" >430,262</td>
#       <td id="T_d5129_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_d5129_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_d5129_row0_col5" class="data row0 col5" >96.90%</td>
#       <td id="T_d5129_row0_col6" class="data row0 col6" >92.81%</td>
#       <td id="T_d5129_row0_col7" class="data row0 col7" >92.72%</td>
#       <td id="T_d5129_row0_col8" class="data row0 col8" >95.43%</td>
#       <td id="T_d5129_row0_col9" class="data row0 col9" >95.36%</td>
#       <td id="T_d5129_row0_col10" class="data row0 col10" >95.39%</td>
#       <td id="T_d5129_row0_col11" class="data row0 col11" >22.2</td>
#     </tr>
#     <tr>
#       <th id="T_d5129_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5129_row1_col0" class="data row1 col0" >CNN Baseline</td>
#       <td id="T_d5129_row1_col1" class="data row1 col1" >CNN</td>
#       <td id="T_d5129_row1_col2" class="data row1 col2" >430,262</td>
#       <td id="T_d5129_row1_col3" class="data row1 col3" >False</td>
#       <td id="T_d5129_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_d5129_row1_col5" class="data row1 col5" >95.52%</td>
#       <td id="T_d5129_row1_col6" class="data row1 col6" >91.19%</td>
#       <td id="T_d5129_row1_col7" class="data row1 col7" >91.34%</td>
#       <td id="T_d5129_row1_col8" class="data row1 col8" >91.11%</td>
#       <td id="T_d5129_row1_col9" class="data row1 col9" >90.95%</td>
#       <td id="T_d5129_row1_col10" class="data row1 col10" >90.99%</td>
#       <td id="T_d5129_row1_col11" class="data row1 col11" >16.9</td>
#     </tr>
#     <tr>
#       <th id="T_d5129_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5129_row2_col0" class="data row2 col0" >MLP Regularizada</td>
#       <td id="T_d5129_row2_col1" class="data row2 col1" >MLP</td>
#       <td id="T_d5129_row2_col2" class="data row2 col2" >235,146</td>
#       <td id="T_d5129_row2_col3" class="data row2 col3" >False</td>
#       <td id="T_d5129_row2_col4" class="data row2 col4" >True</td>
#       <td id="T_d5129_row2_col5" class="data row2 col5" >92.41%</td>
#       <td id="T_d5129_row2_col6" class="data row2 col6" >86.06%</td>
#       <td id="T_d5129_row2_col7" class="data row2 col7" >84.06%</td>
#       <td id="T_d5129_row2_col8" class="data row2 col8" >89.31%</td>
#       <td id="T_d5129_row2_col9" class="data row2 col9" >89.11%</td>
#       <td id="T_d5129_row2_col10" class="data row2 col10" >89.09%</td>
#       <td id="T_d5129_row2_col11" class="data row2 col11" >15.6</td>
#     </tr>
#     <tr>
#       <th id="T_d5129_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5129_row3_col0" class="data row3 col0" >MLP Baseline</td>
#       <td id="T_d5129_row3_col1" class="data row3 col1" >MLP</td>
#       <td id="T_d5129_row3_col2" class="data row3 col2" >235,146</td>
#       <td id="T_d5129_row3_col3" class="data row3 col3" >False</td>
#       <td id="T_d5129_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_d5129_row3_col5" class="data row3 col5" >92.93%</td>
#       <td id="T_d5129_row3_col6" class="data row3 col6" >85.06%</td>
#       <td id="T_d5129_row3_col7" class="data row3 col7" >86.45%</td>
#       <td id="T_d5129_row3_col8" class="data row3 col8" >87.75%</td>
#       <td id="T_d5129_row3_col9" class="data row3 col9" >87.47%</td>
#       <td id="T_d5129_row3_col10" class="data row3 col10" >87.50%</td>
#       <td id="T_d5129_row3_col11" class="data row3 col11" >15.5</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric_cols = ["Test Accuracy", "Test Balanced Acc", "Test Macro-F1"]
plot_df = results_df.copy()

fig, ax = plt.subplots(figsize=(12, 5))
x = np.arange(len(plot_df))
width = 0.24

for i, metric in enumerate(metric_cols):
    ax.bar(x + (i - 1) * width, plot_df[metric], width=width, edgecolor="black", label=metric)

ax.set_xticks(x)
ax.set_xticklabels(plot_df["Experimento"], rotation=15, ha="right")
ax.set_ylim(0.75, 1.0)
ax.set_ylabel("Valor de la métrica")
ax.set_title("Comparación de métricas globales sobre el conjunto de test")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretación
# - Si la accuracy y la balanced accuracy son parecidas, el modelo está tratando de forma relativamente homogénea a las clases.
# - Si la accuracy es bastante mayor que la balanced accuracy, probablemente el modelo está favoreciendo a las clases frecuentes.
# - La macro-F1 es especialmente exigente: castiga tanto baja precisión como bajo recall por clase.
#
# ### Pregunta de reflexión
# ¿Qué experimento parece mejorar más las clases minoritarias, y en qué métrica se nota primero?

# %% [markdown]
# ## 14. Curvas de entrenamiento
#
# Las curvas nos muestran la dinámica del aprendizaje:
#
# - cómo baja la pérdida;
# - cuándo aparece sobreajuste;
# - cuánto se achica la brecha entre entrenamiento y validación.
#
# ### Error conceptual frecuente
# Comparar sin pensar la train loss y la val loss cuando hay augmentation y dropout. En esos casos, el conjunto de entrenamiento es efectivamente más difícil que el de validación.

# %%
def plot_histories_grid(histories: Dict[str, Dict[str, List[float]]], metric_pairs=None):
    if metric_pairs is None:
        metric_pairs = [
            ("train_loss", "val_loss", "Pérdida"),
            ("train_bal_acc", "val_bal_acc", "Balanced Accuracy"),
            ("train_macro_f1", "val_macro_f1", "Macro-F1"),
            ("train_accuracy", "val_accuracy", "Accuracy"),
        ]

    for train_key, val_key, title in metric_pairs:
        fig, axes = plt.subplots(2, 2, figsize=(14, 9), sharex=True)
        axes = axes.flatten()

        for ax, (name, hist) in zip(axes, histories.items()):
            epochs_range = range(1, len(hist[train_key]) + 1)
            ax.plot(epochs_range, hist[train_key], marker="o", linewidth=2, label="Train")
            ax.plot(epochs_range, hist[val_key], marker="s", linewidth=2, label="Val")
            ax.set_title(name.replace("_", " "))
            ax.set_xlabel("Época")
            ax.set_ylabel(title)
            ax.legend()

        fig.suptitle(f"Evolución de {title}", fontsize=16, fontweight="bold", y=0.98)
        plt.tight_layout()
        plt.show()

plot_histories_grid(histories)

# %%
gap_rows = []
for name, hist in histories.items():
    best_epoch = int(np.argmax(hist["val_macro_f1"]))
    gap_rows.append({
        "Experimento": name.replace("_", " "),
        "best_epoch": best_epoch + 1,
        "gap_bal_acc_best_epoch": hist["train_bal_acc"][best_epoch] - hist["val_bal_acc"][best_epoch],
        "gap_macro_f1_best_epoch": hist["train_macro_f1"][best_epoch] - hist["val_macro_f1"][best_epoch],
    })

gap_df = pd.DataFrame(gap_rows)
display(gap_df)
# Out:
#             Experimento  best_epoch  gap_bal_acc_best_epoch  \
# 0          MLP Baseline          19                0.137969
# 1      MLP Regularizada          21                0.124219
# 2          CNN Baseline          24                0.067500
# 3  CNN Regularizada Aug          22                0.000469
#
#    gap_macro_f1_best_epoch
# 0                 0.119981
# 1                 0.115942
# 2                 0.065697
# 3                -0.025769

# %%
fig, ax = plt.subplots(figsize=(10, 4))
x = np.arange(len(gap_df))
width = 0.35

ax.bar(x - width/2, gap_df["gap_bal_acc_best_epoch"], width=width, edgecolor="black", label="Gap Balanced Acc")
ax.bar(x + width/2, gap_df["gap_macro_f1_best_epoch"], width=width, edgecolor="black", label="Gap Macro-F1")

ax.axhline(0.0, color="black", linewidth=1)
ax.set_xticks(x)
ax.set_xticklabels(gap_df["Experimento"], rotation=15, ha="right")
ax.set_ylabel("Train - Val")
ax.set_title("Gap de generalización en la mejor época de validación")
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Mensaje para llevarse
# - Un gap grande `train > val` suele indicar sobreajuste.
# - Si el gap es pequeño y la validación es buena, el modelo está generalizando mejor.
# - En modelos con augmentation y dropout, no es raro que el entrenamiento resulte más duro que la validación.

# %% [markdown]
# ## 15. Anatomía del error: matrices de confusión
#
# Las métricas globales resumen, pero no muestran dónde se equivoca el modelo.
#
# La matriz de confusión sí lo hace.
#
# Vamos a usar matrices normalizadas por fila: cada fila representa una clase real y suma aproximadamente 1. Por eso, la diagonal se interpreta como el recall por clase.

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 13))
axes = axes.flatten()

for ax, exp in zip(axes, EXPERIMENTS):
    name = exp["name"]
    preds = trained_models[name]["test_preds"]
    true = trained_models[name]["test_true"]

    cm = confusion_matrix(true, preds, normalize="true")
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(range(10)))
    disp.plot(ax=ax, cmap="Blues", colorbar=False, values_format=".2f")
    ax.set_title(name.replace("_", " "), fontsize=13, fontweight="bold")
    ax.grid(False)

fig.suptitle("Matrices de confusión normalizadas sobre test", fontsize=16, fontweight="bold", y=0.99)
plt.tight_layout()
plt.show()

# %%
def per_class_recall_from_confusion(y_true, y_pred, num_classes=10):
    cm = confusion_matrix(y_true, y_pred, normalize="true")
    return np.diag(cm)

recall_rows = []
for exp in EXPERIMENTS:
    name = exp["name"]
    recalls = per_class_recall_from_confusion(
        trained_models[name]["test_true"],
        trained_models[name]["test_preds"],
    )
    row = {"Experimento": name.replace("_", " ")}
    for c, value in enumerate(recalls):
        row[f"Clase {c}"] = value
    recall_rows.append(row)

per_class_df = pd.DataFrame(recall_rows).set_index("Experimento")
display(per_class_df)
# Out:
#                        Clase 0   Clase 1   Clase 2   Clase 3   Clase 4  \
# Experimento
# MLP Baseline          0.994898  0.992070  0.906977  0.935644  0.804481
# MLP Regularizada      0.987755  0.982379  0.912791  0.912871  0.841141
# CNN Baseline          0.993878  0.991189  0.975775  0.980198  0.875764
# CNN Regularizada Aug  0.996939  0.992952  0.965116  0.962376  0.933809
#
#                        Clase 5   Clase 6   Clase 7   Clase 8   Clase 9
# Experimento
# MLP Baseline          0.788117  0.921712  0.864786  0.699179  0.839445
# MLP Regularizada      0.847534  0.926931  0.890078  0.723819  0.886026
# CNN Baseline          0.883408  0.931106  0.856031  0.767967  0.839445
# CNN Regularizada Aug  0.938341  0.968685  0.944553  0.907598  0.925669

# %%
fig, ax = plt.subplots(figsize=(12, 5))
im = ax.imshow(per_class_df.values, aspect="auto", cmap="YlGnBu", vmin=0.0, vmax=1.0)

ax.set_xticks(np.arange(per_class_df.shape[1]))
ax.set_xticklabels(per_class_df.columns, rotation=45, ha="right")
ax.set_yticks(np.arange(per_class_df.shape[0]))
ax.set_yticklabels(per_class_df.index)
ax.set_title("Recall por clase en el conjunto de test")
fig.colorbar(im, ax=ax, label="Recall")
plt.tight_layout()
plt.show()

# %%
def top_confusions(y_true, y_pred, top_k=10):
    cm = confusion_matrix(y_true, y_pred)
    np.fill_diagonal(cm, 0)
    pairs = []
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            if cm[i, j] > 0:
                pairs.append((i, j, cm[i, j]))
    pairs = sorted(pairs, key=lambda x: x[2], reverse=True)
    return pairs[:top_k]

for exp in EXPERIMENTS:
    name = exp["name"]
    print(f"\n{name}")
    for i, j, n in top_confusions(trained_models[name]["test_true"], trained_models[name]["test_preds"], top_k=5):
        print(f"  Clase real {i} → predicha como {j}: {n} veces")
# Out:
# MLP_Baseline
#   Clase real 4 → predicha como 9: 101 veces
#   Clase real 8 → predicha como 3: 82 veces
#   Clase real 5 → predicha como 3: 78 veces
#   Clase real 8 → predicha como 1: 66 veces
#   Clase real 7 → predicha como 2: 60 veces
#
# MLP_Regularizada
#   Clase real 4 → predicha como 9: 115 veces
#   Clase real 8 → predicha como 3: 60 veces
#   Clase real 8 → predicha como 5: 56 veces
#   Clase real 5 → predicha como 3: 53 veces
#   Clase real 8 → predicha como 9: 48 veces
#
# CNN_Baseline
#   Clase real 7 → predicha como 2: 81 veces
#   Clase real 8 → predicha como 3: 80 veces
#   Clase real 5 → predicha como 3: 62 veces
#   Clase real 4 → predicha como 9: 58 veces
#   Clase real 9 → predicha como 7: 49 veces
#
# CNN_Regularizada_Aug
#   Clase real 4 → predicha como 9: 45 veces
#   Clase real 7 → predicha como 2: 27 veces
#   Clase real 8 → predicha como 0: 27 veces
#   Clase real 9 → predicha como 7: 26 veces
#   Clase real 5 → predicha como 3: 22 veces

# %% [markdown]
# ### Interpretación
# - Las clases minoritarias suelen mostrar recalls más bajos en los modelos baseline.
# - Cuando aparece `class-weighted loss`, el modelo suele dedicar más capacidad a no abandonar esas clases.
# - La CNN, incluso sin regularización, tiende a cometer errores más “estructurados” y menos arbitrarios que la MLP.
#
# ### Pregunta para discutir
# ¿Las mejoras en las clases minoritarias vienen más por la arquitectura, por la regularización, o por la combinación de ambas?

# %% [markdown]
# ## 16. Discusión conceptual integradora
#
# A esta altura ya deberías poder sostener varias ideas importantes con evidencia empírica.
#
# ### 16.1 MLP vs CNN
# La MLP recibe una imagen como un vector. Eso le quita estructura espacial al problema. La CNN, en cambio, aprovecha:
#
# - vecindad local,
# - compartición de pesos,
# - jerarquía de patrones.
#
# Por eso no sorprende que, incluso con más parámetros, la CNN generalice mejor en imágenes.
#
# ### 16.2 Overfitting
# Cuando la pérdida de entrenamiento cae muy rápido y la de validación deja de acompañar, aparece el sobreajuste. En datasets pequeños esto es esperable, especialmente en modelos densos.
#
# ### 16.3 Regularización
# - **Dropout** dificulta la co-adaptación de neuronas.
# - **Weight decay** desalienta pesos excesivamente grandes.
# - **Augmentation** vuelve más difícil el entrenamiento y empuja a aprender invariancias útiles.
# - **Class-weighted loss** compensa parcialmente el sesgo estadístico del dataset.
#
# ### 16.4 Métricas
# - **Accuracy**: útil, pero insuficiente si hay desbalance.
# - **Balanced Accuracy**: excelente para ver si el modelo ignora clases.
# - **Macro-F1**: particularmente severa y muy informativa.
#
# ### Mensaje para llevarse
# En Deep Learning no alcanza con mirar un número final. Hay que entender:
#
# - el régimen de datos,
# - la arquitectura,
# - la regularización,
# - las métricas,
# - y la estructura de los errores.

# %% [markdown]
# ## 17. Preguntas para clase
#
# 1. ¿Por qué el MNIST original puede ser demasiado fácil para comparar modelos?
# 2. ¿Qué evidencia concreta de overfitting aparece en la MLP baseline?
# 3. ¿Por qué una CNN puede generalizar mejor aunque tenga más parámetros?
# 4. ¿En qué sentido el data augmentation actúa como regularizador?
# 5. ¿Qué diferencia conceptual hay entre balanced accuracy y macro-F1?
# 6. ¿Qué te dicen las matrices de confusión que no te dice la accuracy?
# 7. ¿Qué pasaría si elimináramos por completo las clases 8 y 9 del entrenamiento?
# 8. ¿Qué esperarías que ocurra si duplicamos el tamaño del subset manteniendo el mismo desbalance?

# %% [markdown]
# ## 18. Extensiones sugeridas
#
# Estas extensiones son ideales para convertir esta guía en una consigna más abierta:
#
# - agregar `BatchNorm` a la CNN;
# - comparar `class-weighted loss` versus `weighted sampling`;
# - modificar el perfil de desbalance;
# - reducir todavía más el tamaño del dataset;
# - repetir el experimento con distintas semillas;
# - probar una CNN con una capa adicional;
# - analizar ejemplos concretos mal clasificados;
# - registrar también precision y recall por clase;
# - comparar el mismo experimento sin normalización;
# - estudiar cómo cambia el resultado si elegimos el mejor modelo por `val_bal_acc` en lugar de `val_macro_f1`.

# %%
training_param_grid = {
    "dropout": [0.0, 0.1, 0.25, 0.4],
    "weight_decay": [0.0, 1e-5, 1e-4, 1e-3],
    'learning_rate': [1e-2, 3e-3, 1e-3, 3e-4],

    "augmentation": [False, True],
    "class_weighted_loss": [False, True],
    "weighted_sampling": [False, True],
}

# %%
def grid_to_experiments(param_grid: dict, prefix: str = "EXP") -> list[dict]:
    keys = list(param_grid.keys())
    values = list(param_grid.values())

    experiments = []

    for idx, combo in enumerate(itertools.product(*values), start=1):
        exp = dict(zip(keys, combo))
        exp["name"] = f"{prefix}_{idx:03d}"
        experiments.append(exp)

    return experiments

training_experiments = grid_to_experiments(training_param_grid, prefix="TRAIN")

# %%
len(training_experiments)
# Out:
# 512

# %%
def compute_metrics_optim(y_true, y_pred) -> Dict[str, float]:
    y_true = y_true.detach().cpu().numpy()

    if y_pred.ndim > 1:
        y_pred = y_pred.argmax(dim=1)

    y_pred = y_pred.detach().cpu().numpy()

    return {
        "accuracy": accuracy_score(y_true, y_pred),
        "balanced_accuracy": balanced_accuracy_score(y_true, y_pred),
        "macro_f1": f1_score(y_true, y_pred, average="macro"),
    }

# %%
def run_epoch_optim(model: nn.Module, loader: DataLoader, criterion, optimizer=None, device=device):
    """Ejecuta una época completa de train o val y devuelve la loss promedio."""
    if optimizer:
        model.train()
    else:
        model.eval()

    total_loss = 0.0
    total = 0
    all_labels = []
    all_preds = []

    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)

        if optimizer:
            predictions = model(images)
        else:
            with torch.no_grad():
                predictions = model(images)

        loss = criterion(predictions, labels)

        if optimizer:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        total_loss += loss.item() * images.size(0)
        total += labels.size(0)
        all_labels.append(labels.detach())
        all_preds.append(predictions.detach().argmax(dim=1))

    epoch_labels = torch.cat(all_labels)
    epoch_preds = torch.cat(all_preds)
    metrics = compute_metrics_optim(epoch_labels, epoch_preds)

    return total_loss / total, metrics['macro_f1']

# %%
def train_model_optim(
    model: nn.Module,
    train_loader: DataLoader,
    val_loader: DataLoader,
    epochs: int,
    lr: float,
    weight_decay: float = 0.0,
    class_weighted_loss: bool = False,
    early_stopping_patience: Optional[int] = None,
    device: torch.device = device,
    model_name: str = 'Modelo',
    verbose: bool = False,
):
    """Entrena un modelo, guarda el mejor estado y devuelve history."""

    model = model.to(device)

    weights = None
    if class_weighted_loss:
        weights = compute_class_weights(train_labels).to(device)

    criterion = nn.CrossEntropyLoss(weight=weights)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    history = {
        'train_loss': [],
        'train_macro_f1': [],
        'val_loss': [],
        'val_macro_f1': [],
    }

    best_macro_f1 = 0.0
    best_model = None

    patience_counter = 0

    if verbose:
        print(f"\n{'='*60}")
        print(f" Entrenando: {model_name}")
        print(f" Parámetros: {count_parameters(model):,}")
        print(f" Épocas: {epochs} | LR: {lr} | Weight Decay: {weight_decay}")
        print(f"{'='*60}")
    
    start_time = time.time()

    for epoch in range(1, epochs + 1):
        train_loss, train_macro_f1 = run_epoch_optim(
            model=model, loader=train_loader, criterion=criterion, optimizer=optimizer, device=device
        )
        val_loss, val_macro_f1 = run_epoch_optim(
            model=model, loader=val_loader, criterion=criterion, device=device
        )

        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_macro_f1'].append(train_macro_f1)
        history['val_macro_f1'].append(val_macro_f1)

        if val_macro_f1 > best_macro_f1:
            best_model = copy.deepcopy(model.state_dict())
            best_macro_f1 = val_macro_f1
            patience_counter = 0
        else:
            patience_counter += 1

        if verbose and (epoch % 5 == 0 or epoch == 1):
            print(f"  Época {epoch:3d}/{epochs}  |  "
                  f"Train Loss: {train_loss:.4f}  Macro-F1: {train_macro_f1 * 100:.2f}%  |  "
                  f"Val Loss: {val_loss:.4f}  Macro-F1: {val_macro_f1 * 100:.2f}%")    

        if early_stopping_patience is not None and patience_counter >= early_stopping_patience:
            if verbose:
                print(f"Entrenamiento detenido en la época {epoch}")
            break

    elapsed = time.time() - start_time
    model.load_state_dict(best_model)
    return model, history, elapsed, best_macro_f1

# %%
results_tr = []
trained_models_tr = {}
histories_tr = {}

total = len(training_experiments)
for i, exp in enumerate(training_experiments, start=1):
    print(f"\n{'='*70}")
    print(f"🚀 Ejecutando experimento: {exp['name']} | {i}/{total}")
    print(f"{'='*70}")

    train_loader, val_loader, test_loader = make_loaders(
        batch_size=CONFIG["batch_size"],
        augmentation=exp["augmentation"],
        weighted_sampling=exp["weighted_sampling"],
        num_workers=CONFIG["num_workers"],
    )

    model = SimpleCNN(dropout=exp['dropout'])

    model, history, elapsed, val_macro_f1 = train_model_optim(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        epochs=CONFIG["epochs"],
        lr=exp["learning_rate"],
        weight_decay=exp["weight_decay"],
        class_weighted_loss=exp["class_weighted_loss"],
        early_stopping_patience=CONFIG["early_stopping_patience"],
        device=device,
        model_name=exp['name'],
        verbose=False,
    )
    print(f'F1: {val_macro_f1}')
    print(f'Elapsed: {elapsed:.2f}s')

    trained_models_tr[exp["name"]] = {
        "model": model,
        "val_macro_f1": val_macro_f1,
        'time': elapsed
    }
    histories_tr[exp["name"]] = history
# Out:
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_001 | 1/512
# ======================================================================
# F1: 0.7941988232755618
# Elapsed: 9.03s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_002 | 2/512
# ======================================================================
# F1: 0.9130473884775249
# Elapsed: 8.99s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_003 | 3/512
# ======================================================================
# F1: 0.9364594438546726
# Elapsed: 8.62s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_004 | 4/512
# ======================================================================
# F1: 0.8878116101073823
# Elapsed: 8.85s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_005 | 5/512
# ======================================================================
# F1: 0.9574852109565215
# Elapsed: 11.44s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_006 | 6/512
# ======================================================================
# F1: 0.9629028774514202
# Elapsed: 11.34s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_007 | 7/512
# ======================================================================
# F1: 0.9401738203983104
# Elapsed: 11.46s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_008 | 8/512
# ======================================================================
# F1: 0.876659816180861
# Elapsed: 11.47s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_009 | 9/512
# ======================================================================
# F1: 0.9080143499510236
# Elapsed: 8.71s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_010 | 10/512
# ======================================================================
# F1: 0.9182633650640037
# Elapsed: 8.70s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_011 | 11/512
# ======================================================================
# F1: 0.9091830282397411
# Elapsed: 8.89s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_012 | 12/512
# ======================================================================
# F1: 0.8969238531237181
# Elapsed: 8.99s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_013 | 13/512
# ======================================================================
# F1: 0.9219781625126966
# Elapsed: 11.43s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_014 | 14/512
# ======================================================================
# F1: 0.9532346725528773
# Elapsed: 11.36s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_015 | 15/512
# ======================================================================
# F1: 0.9569346849858175
# Elapsed: 11.44s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_016 | 16/512
# ======================================================================
# F1: 0.9091916053665263
# Elapsed: 11.41s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_017 | 17/512
# ======================================================================
# F1: 0.9023421048213057
# Elapsed: 8.92s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_018 | 18/512
# ======================================================================
# F1: 0.8971574194861128
# Elapsed: 8.91s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_019 | 19/512
# ======================================================================
# F1: 0.9019133279868861
# Elapsed: 8.56s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_020 | 20/512
# ======================================================================
# F1: 0.8635624496186001
# Elapsed: 8.86s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_021 | 21/512
# ======================================================================
# F1: 0.906719310422862
# Elapsed: 11.82s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_022 | 22/512
# ======================================================================
# F1: 0.9366188774370181
# Elapsed: 11.42s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_023 | 23/512
# ======================================================================
# F1: 0.9012272040061984
# Elapsed: 11.62s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_024 | 24/512
# ======================================================================
# F1: 0.8303178189048237
# Elapsed: 11.72s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_025 | 25/512
# ======================================================================
# F1: 0.8617035699521018
# Elapsed: 8.90s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_026 | 26/512
# ======================================================================
# F1: 0.8673927464906477
# Elapsed: 8.44s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_027 | 27/512
# ======================================================================
# F1: 0.832942430193943
# Elapsed: 9.22s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_028 | 28/512
# ======================================================================
# F1: 0.6769259130668227
# Elapsed: 8.82s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_029 | 29/512
# ======================================================================
# F1: 0.6863333191237844
# Elapsed: 11.46s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_030 | 30/512
# ======================================================================
# F1: 0.8843489359561187
# Elapsed: 11.78s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_031 | 31/512
# ======================================================================
# F1: 0.8782204256301387
# Elapsed: 11.29s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_032 | 32/512
# ======================================================================
# F1: 0.3763419651261823
# Elapsed: 11.43s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_033 | 33/512
# ======================================================================
# F1: 0.902752596380853
# Elapsed: 8.91s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_034 | 34/512
# ======================================================================
# F1: 0.9077049689170826
# Elapsed: 8.38s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_035 | 35/512
# ======================================================================
# F1: 0.9093381035749522
# Elapsed: 9.08s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_036 | 36/512
# ======================================================================
# F1: 0.8956188548506315
# Elapsed: 9.28s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_037 | 37/512
# ======================================================================
# F1: 0.9161152079837251
# Elapsed: 11.17s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_038 | 38/512
# ======================================================================
# F1: 0.9077945767397333
# Elapsed: 11.20s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_039 | 39/512
# ======================================================================
# F1: 0.9124432661550544
# Elapsed: 11.55s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_040 | 40/512
# ======================================================================
# F1: 0.8700230222166478
# Elapsed: 11.30s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_041 | 41/512
# ======================================================================
# F1: 0.92721372546041
# Elapsed: 8.88s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_042 | 42/512
# ======================================================================
# F1: 0.9083148870825128
# Elapsed: 8.89s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_043 | 43/512
# ======================================================================
# F1: 0.9201112174088573
# Elapsed: 9.07s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_044 | 44/512
# ======================================================================
# F1: 0.8990108702669808
# Elapsed: 9.00s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_045 | 45/512
# ======================================================================
# F1: 0.9143454028947537
# Elapsed: 11.34s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_046 | 46/512
# ======================================================================
# F1: 0.9419949446359158
# Elapsed: 11.50s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_047 | 47/512
# ======================================================================
# F1: 0.9583956878180675
# Elapsed: 11.47s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_048 | 48/512
# ======================================================================
# F1: 0.899774542323059
# Elapsed: 11.39s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_049 | 49/512
# ======================================================================
# F1: 0.8951229881502561
# Elapsed: 8.93s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_050 | 50/512
# ======================================================================
# F1: 0.9071423245227821
# Elapsed: 8.94s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_051 | 51/512
# ======================================================================
# F1: 0.8708126346458686
# Elapsed: 8.94s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_052 | 52/512
# ======================================================================
# F1: 0.838673375338273
# Elapsed: 9.09s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_053 | 53/512
# ======================================================================
# F1: 0.9098851376890759
# Elapsed: 11.46s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_054 | 54/512
# ======================================================================
# F1: 0.9179411063761306
# Elapsed: 11.49s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_055 | 55/512
# ======================================================================
# F1: 0.8966198060759536
# Elapsed: 11.44s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_056 | 56/512
# ======================================================================
# F1: 0.865794066889414
# Elapsed: 11.44s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_057 | 57/512
# ======================================================================
# F1: 0.8167921150017303
# Elapsed: 9.03s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_058 | 58/512
# ======================================================================
# F1: 0.8534330212134609
# Elapsed: 9.04s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_059 | 59/512
# ======================================================================
# F1: 0.835001524268572
# Elapsed: 9.00s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_060 | 60/512
# ======================================================================
# F1: 0.717074139565677
# Elapsed: 8.93s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_061 | 61/512
# ======================================================================
# F1: 0.6942670161700069
# Elapsed: 11.44s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_062 | 62/512
# ======================================================================
# F1: 0.8184915926387711
# Elapsed: 11.25s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_063 | 63/512
# ======================================================================
# F1: 0.8326380744576639
# Elapsed: 10.55s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_064 | 64/512
# ======================================================================
# F1: 0.6094199306374404
# Elapsed: 10.76s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_065 | 65/512
# ======================================================================
# F1: 0.8908827847812342
# Elapsed: 8.28s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_066 | 66/512
# ======================================================================
# F1: 0.9370978372345423
# Elapsed: 8.26s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_067 | 67/512
# ======================================================================
# F1: 0.9360371810154273
# Elapsed: 8.25s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_068 | 68/512
# ======================================================================
# F1: 0.9127290984456021
# Elapsed: 8.26s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_069 | 69/512
# ======================================================================
# F1: 0.9303864923112126
# Elapsed: 10.61s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_070 | 70/512
# ======================================================================
# F1: 0.9464038263865182
# Elapsed: 10.59s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_071 | 71/512
# ======================================================================
# F1: 0.8843661407087339
# Elapsed: 10.87s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_072 | 72/512
# ======================================================================
# F1: 0.8688714995894419
# Elapsed: 11.00s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_073 | 73/512
# ======================================================================
# F1: 0.9210842335425962
# Elapsed: 8.60s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_074 | 74/512
# ======================================================================
# F1: 0.8944551285107891
# Elapsed: 8.26s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_075 | 75/512
# ======================================================================
# F1: 0.9162978737970955
# Elapsed: 8.26s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_076 | 76/512
# ======================================================================
# F1: 0.9093324042049631
# Elapsed: 8.35s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_077 | 77/512
# ======================================================================
# F1: 0.9511229184705163
# Elapsed: 10.52s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_078 | 78/512
# ======================================================================
# F1: 0.9678358841251923
# Elapsed: 10.51s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_079 | 79/512
# ======================================================================
# F1: 0.9358003347770936
# Elapsed: 10.65s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_080 | 80/512
# ======================================================================
# F1: 0.9216174479074295
# Elapsed: 10.63s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_081 | 81/512
# ======================================================================
# F1: 0.8928960896331718
# Elapsed: 8.32s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_082 | 82/512
# ======================================================================
# F1: 0.9061757073238095
# Elapsed: 8.35s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_083 | 83/512
# ======================================================================
# F1: 0.8987734992471784
# Elapsed: 8.23s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_084 | 84/512
# ======================================================================
# F1: 0.8467184357602864
# Elapsed: 8.21s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_085 | 85/512
# ======================================================================
# F1: 0.893060877603555
# Elapsed: 10.69s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_086 | 86/512
# ======================================================================
# F1: 0.9239822914581094
# Elapsed: 10.64s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_087 | 87/512
# ======================================================================
# F1: 0.8922591810514623
# Elapsed: 10.58s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_088 | 88/512
# ======================================================================
# F1: 0.8528447967817845
# Elapsed: 10.66s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_089 | 89/512
# ======================================================================
# F1: 0.8522527419799937
# Elapsed: 8.29s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_090 | 90/512
# ======================================================================
# F1: 0.8490590213777386
# Elapsed: 8.35s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_091 | 91/512
# ======================================================================
# F1: 0.865467859650594
# Elapsed: 8.23s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_092 | 92/512
# ======================================================================
# F1: 0.7861725663120841
# Elapsed: 8.33s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_093 | 93/512
# ======================================================================
# F1: 0.6551963353200388
# Elapsed: 10.74s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_094 | 94/512
# ======================================================================
# F1: 0.8646748309430295
# Elapsed: 10.76s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_095 | 95/512
# ======================================================================
# F1: 0.8720994722491922
# Elapsed: 10.64s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_096 | 96/512
# ======================================================================
# F1: 0.608224182565812
# Elapsed: 10.80s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_097 | 97/512
# ======================================================================
# F1: 0.8879679552276878
# Elapsed: 8.29s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_098 | 98/512
# ======================================================================
# F1: 0.9519680039849765
# Elapsed: 8.36s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_099 | 99/512
# ======================================================================
# F1: 0.9104360205934476
# Elapsed: 8.15s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_100 | 100/512
# ======================================================================
# F1: 0.9134764587768446
# Elapsed: 8.16s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_101 | 101/512
# ======================================================================
# F1: 0.9109963594837882
# Elapsed: 10.51s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_102 | 102/512
# ======================================================================
# F1: 0.9605858048963123
# Elapsed: 10.69s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_103 | 103/512
# ======================================================================
# F1: 0.9159337218449703
# Elapsed: 10.59s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_104 | 104/512
# ======================================================================
# F1: 0.8717398728762019
# Elapsed: 10.70s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_105 | 105/512
# ======================================================================
# F1: 0.9013041481569584
# Elapsed: 8.26s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_106 | 106/512
# ======================================================================
# F1: 0.9096354455010436
# Elapsed: 8.20s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_107 | 107/512
# ======================================================================
# F1: 0.9227799582916922
# Elapsed: 8.30s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_108 | 108/512
# ======================================================================
# F1: 0.9044054298129496
# Elapsed: 8.32s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_109 | 109/512
# ======================================================================
# F1: 0.9296128232403198
# Elapsed: 10.74s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_110 | 110/512
# ======================================================================
# F1: 0.9555780360593064
# Elapsed: 10.80s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_111 | 111/512
# ======================================================================
# F1: 0.9579237114113486
# Elapsed: 10.74s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_112 | 112/512
# ======================================================================
# F1: 0.923307419467676
# Elapsed: 10.71s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_113 | 113/512
# ======================================================================
# F1: 0.9097915654800375
# Elapsed: 8.26s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_114 | 114/512
# ======================================================================
# F1: 0.9008900944771842
# Elapsed: 8.30s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_115 | 115/512
# ======================================================================
# F1: 0.8874825622738479
# Elapsed: 8.19s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_116 | 116/512
# ======================================================================
# F1: 0.8909157897822219
# Elapsed: 8.10s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_117 | 117/512
# ======================================================================
# F1: 0.9100456343332182
# Elapsed: 10.56s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_118 | 118/512
# ======================================================================
# F1: 0.9139358014707591
# Elapsed: 11.09s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_119 | 119/512
# ======================================================================
# F1: 0.9076036204948796
# Elapsed: 10.85s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_120 | 120/512
# ======================================================================
# F1: 0.8593344877790262
# Elapsed: 10.91s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_121 | 121/512
# ======================================================================
# F1: 0.7852546455803028
# Elapsed: 8.37s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_122 | 122/512
# ======================================================================
# F1: 0.8955959176892812
# Elapsed: 8.39s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_123 | 123/512
# ======================================================================
# F1: 0.8604976718436352
# Elapsed: 8.39s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_124 | 124/512
# ======================================================================
# F1: 0.7013003007548406
# Elapsed: 8.33s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_125 | 125/512
# ======================================================================
# F1: 0.6152471520556534
# Elapsed: 10.68s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_126 | 126/512
# ======================================================================
# F1: 0.8393071780468635
# Elapsed: 10.70s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_127 | 127/512
# ======================================================================
# F1: 0.8635728436399065
# Elapsed: 10.59s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_128 | 128/512
# ======================================================================
# F1: 0.6393005511283333
# Elapsed: 10.65s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_129 | 129/512
# ======================================================================
# F1: 0.8700623146357606
# Elapsed: 8.38s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_130 | 130/512
# ======================================================================
# F1: 0.922977425949702
# Elapsed: 8.50s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_131 | 131/512
# ======================================================================
# F1: 0.939200925575248
# Elapsed: 8.48s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_132 | 132/512
# ======================================================================
# F1: 0.8889836580491688
# Elapsed: 8.40s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_133 | 133/512
# ======================================================================
# F1: 0.788756314573358
# Elapsed: 10.83s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_134 | 134/512
# ======================================================================
# F1: 0.9504950497103769
# Elapsed: 10.92s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_135 | 135/512
# ======================================================================
# F1: 0.9241966721978763
# Elapsed: 10.76s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_136 | 136/512
# ======================================================================
# F1: 0.9163520124249228
# Elapsed: 10.92s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_137 | 137/512
# ======================================================================
# F1: 0.9130233114202975
# Elapsed: 8.31s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_138 | 138/512
# ======================================================================
# F1: 0.9014632534014778
# Elapsed: 8.16s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_139 | 139/512
# ======================================================================
# F1: 0.9111145944389601
# Elapsed: 8.08s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_140 | 140/512
# ======================================================================
# F1: 0.908431897750123
# Elapsed: 8.34s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_141 | 141/512
# ======================================================================
# F1: 0.9190903733476301
# Elapsed: 10.66s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_142 | 142/512
# ======================================================================
# F1: 0.9496986495750545
# Elapsed: 10.58s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_143 | 143/512
# ======================================================================
# F1: 0.9489880040908674
# Elapsed: 10.62s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_144 | 144/512
# ======================================================================
# F1: 0.8891568100034537
# Elapsed: 10.72s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_145 | 145/512
# ======================================================================
# F1: 0.8934834241197196
# Elapsed: 8.40s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_146 | 146/512
# ======================================================================
# F1: 0.893531062173885
# Elapsed: 8.27s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_147 | 147/512
# ======================================================================
# F1: 0.8843705642245576
# Elapsed: 8.30s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_148 | 148/512
# ======================================================================
# F1: 0.8598791498526296
# Elapsed: 8.27s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_149 | 149/512
# ======================================================================
# F1: 0.9140164883452405
# Elapsed: 10.72s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_150 | 150/512
# ======================================================================
# F1: 0.9356744693961858
# Elapsed: 10.74s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_151 | 151/512
# ======================================================================
# F1: 0.9388900962968629
# Elapsed: 10.72s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_152 | 152/512
# ======================================================================
# F1: 0.8590113485983004
# Elapsed: 10.50s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_153 | 153/512
# ======================================================================
# F1: 0.8194945147953877
# Elapsed: 8.18s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_154 | 154/512
# ======================================================================
# F1: 0.8660858202612174
# Elapsed: 8.28s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_155 | 155/512
# ======================================================================
# F1: 0.8507392489741473
# Elapsed: 8.23s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_156 | 156/512
# ======================================================================
# F1: 0.7533655148318212
# Elapsed: 8.18s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_157 | 157/512
# ======================================================================
# F1: 0.7877367119851242
# Elapsed: 10.77s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_158 | 158/512
# ======================================================================
# F1: 0.8850362341851472
# Elapsed: 10.71s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_159 | 159/512
# ======================================================================
# F1: 0.8206844275621101
# Elapsed: 10.63s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_160 | 160/512
# ======================================================================
# F1: 0.3465359535171361
# Elapsed: 10.94s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_161 | 161/512
# ======================================================================
# F1: 0.9258197478598639
# Elapsed: 8.31s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_162 | 162/512
# ======================================================================
# F1: 0.9121342901391095
# Elapsed: 8.27s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_163 | 163/512
# ======================================================================
# F1: 0.9426385032793186
# Elapsed: 8.15s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_164 | 164/512
# ======================================================================
# F1: 0.9221522690440358
# Elapsed: 8.26s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_165 | 165/512
# ======================================================================
# F1: 0.7680088530274651
# Elapsed: 10.47s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_166 | 166/512
# ======================================================================
# F1: 0.9676685976364562
# Elapsed: 10.66s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_167 | 167/512
# ======================================================================
# F1: 0.9323997129198413
# Elapsed: 10.56s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_168 | 168/512
# ======================================================================
# F1: 0.8668904053197488
# Elapsed: 10.83s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_169 | 169/512
# ======================================================================
# F1: 0.9319833032579112
# Elapsed: 8.24s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_170 | 170/512
# ======================================================================
# F1: 0.9374874805416354
# Elapsed: 8.17s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_171 | 171/512
# ======================================================================
# F1: 0.9272894511173438
# Elapsed: 8.13s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_172 | 172/512
# ======================================================================
# F1: 0.9116271919235995
# Elapsed: 8.11s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_173 | 173/512
# ======================================================================
# F1: 0.9178893011337582
# Elapsed: 10.56s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_174 | 174/512
# ======================================================================
# F1: 0.9353695371811209
# Elapsed: 10.59s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_175 | 175/512
# ======================================================================
# F1: 0.9611530204850747
# Elapsed: 10.78s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_176 | 176/512
# ======================================================================
# F1: 0.893130296410462
# Elapsed: 10.72s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_177 | 177/512
# ======================================================================
# F1: 0.8984524832223204
# Elapsed: 8.25s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_178 | 178/512
# ======================================================================
# F1: 0.896092797632021
# Elapsed: 8.24s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_179 | 179/512
# ======================================================================
# F1: 0.9204566508923007
# Elapsed: 8.09s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_180 | 180/512
# ======================================================================
# F1: 0.8558971172027035
# Elapsed: 8.06s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_181 | 181/512
# ======================================================================
# F1: 0.8674664351361348
# Elapsed: 10.64s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_182 | 182/512
# ======================================================================
# F1: 0.9396334134350445
# Elapsed: 10.59s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_183 | 183/512
# ======================================================================
# F1: 0.9136552462943552
# Elapsed: 10.62s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_184 | 184/512
# ======================================================================
# F1: 0.9034946344168236
# Elapsed: 10.55s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_185 | 185/512
# ======================================================================
# F1: 0.8426913020263745
# Elapsed: 8.14s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_186 | 186/512
# ======================================================================
# F1: 0.8618155214250303
# Elapsed: 8.15s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_187 | 187/512
# ======================================================================
# F1: 0.839037519895828
# Elapsed: 8.07s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_188 | 188/512
# ======================================================================
# F1: 0.7517238210407942
# Elapsed: 8.21s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_189 | 189/512
# ======================================================================
# F1: 0.6945030050059993
# Elapsed: 10.60s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_190 | 190/512
# ======================================================================
# F1: 0.8721028816956707
# Elapsed: 10.69s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_191 | 191/512
# ======================================================================
# F1: 0.8346467532859302
# Elapsed: 10.73s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_192 | 192/512
# ======================================================================
# F1: 0.47494711346492435
# Elapsed: 10.60s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_193 | 193/512
# ======================================================================
# F1: 0.9168692551033841
# Elapsed: 8.09s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_194 | 194/512
# ======================================================================
# F1: 0.9522503627261244
# Elapsed: 8.18s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_195 | 195/512
# ======================================================================
# F1: 0.9164840488767776
# Elapsed: 8.29s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_196 | 196/512
# ======================================================================
# F1: 0.9083087901922531
# Elapsed: 8.24s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_197 | 197/512
# ======================================================================
# F1: 0.9337570625714713
# Elapsed: 10.44s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_198 | 198/512
# ======================================================================
# F1: 0.9528334650859926
# Elapsed: 10.49s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_199 | 199/512
# ======================================================================
# F1: 0.69957105668572
# Elapsed: 10.49s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_200 | 200/512
# ======================================================================
# F1: 0.8755453163093124
# Elapsed: 10.50s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_201 | 201/512
# ======================================================================
# F1: 0.9288494800045897
# Elapsed: 8.33s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_202 | 202/512
# ======================================================================
# F1: 0.904143594005782
# Elapsed: 8.37s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_203 | 203/512
# ======================================================================
# F1: 0.9074094661545008
# Elapsed: 8.45s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_204 | 204/512
# ======================================================================
# F1: 0.9073741536516232
# Elapsed: 8.48s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_205 | 205/512
# ======================================================================
# F1: 0.9468241847311134
# Elapsed: 10.64s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_206 | 206/512
# ======================================================================
# F1: 0.9392940462687329
# Elapsed: 10.58s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_207 | 207/512
# ======================================================================
# F1: 0.9486689597185436
# Elapsed: 10.66s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_208 | 208/512
# ======================================================================
# F1: 0.9374065799964366
# Elapsed: 10.65s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_209 | 209/512
# ======================================================================
# F1: 0.904586008054628
# Elapsed: 8.35s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_210 | 210/512
# ======================================================================
# F1: 0.9108470315086936
# Elapsed: 8.35s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_211 | 211/512
# ======================================================================
# F1: 0.9043578058085397
# Elapsed: 8.36s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_212 | 212/512
# ...
# F1: 0.8359525976916926
# Elapsed: 8.17s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_443 | 443/512
# ======================================================================
# F1: 0.8343445282656294
# Elapsed: 8.11s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_444 | 444/512
# ======================================================================
# F1: 0.7259798084857791
# Elapsed: 8.18s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_445 | 445/512
# ======================================================================
# F1: 0.6825774449176629
# Elapsed: 10.50s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_446 | 446/512
# ======================================================================
# F1: 0.8472757821190955
# Elapsed: 10.53s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_447 | 447/512
# ======================================================================
# F1: 0.8294056538392386
# Elapsed: 10.63s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_448 | 448/512
# ======================================================================
# F1: 0.4067622428248865
# Elapsed: 10.50s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_449 | 449/512
# ======================================================================
# F1: 0.9056117134800157
# Elapsed: 8.34s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_450 | 450/512
# ======================================================================
# F1: 0.9250347241254137
# Elapsed: 8.09s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_451 | 451/512
# ======================================================================
# F1: 0.9387248895391316
# Elapsed: 8.09s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_452 | 452/512
# ======================================================================
# F1: 0.9122492034443817
# Elapsed: 8.21s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_453 | 453/512
# ======================================================================
# F1: 0.9313226912183644
# Elapsed: 10.54s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_454 | 454/512
# ======================================================================
# F1: 0.9237904927003294
# Elapsed: 10.88s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_455 | 455/512
# ======================================================================
# F1: 0.07738602135565147
# Elapsed: 10.71s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_456 | 456/512
# ======================================================================
# F1: 0.9067152727266061
# Elapsed: 10.60s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_457 | 457/512
# ======================================================================
# F1: 0.9133370670980447
# Elapsed: 8.14s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_458 | 458/512
# ======================================================================
# F1: 0.9175882143532601
# Elapsed: 8.24s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_459 | 459/512
# ======================================================================
# F1: 0.9340538978578067
# Elapsed: 8.52s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_460 | 460/512
# ======================================================================
# F1: 0.9127084378030226
# Elapsed: 9.25s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_461 | 461/512
# ======================================================================
# F1: 0.9113265571370736
# Elapsed: 10.99s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_462 | 462/512
# ======================================================================
# F1: 0.970025618336185
# Elapsed: 11.55s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_463 | 463/512
# ======================================================================
# F1: 0.9343977736036111
# Elapsed: 11.26s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_464 | 464/512
# ======================================================================
# F1: 0.9187869847236169
# Elapsed: 10.74s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_465 | 465/512
# ======================================================================
# F1: 0.8851441035485428
# Elapsed: 8.92s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_466 | 466/512
# ======================================================================
# F1: 0.9150819497793785
# Elapsed: 8.78s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_467 | 467/512
# ======================================================================
# F1: 0.9124660955755661
# Elapsed: 8.81s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_468 | 468/512
# ======================================================================
# F1: 0.841664926489836
# Elapsed: 8.83s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_469 | 469/512
# ======================================================================
# F1: 0.9085202249297947
# Elapsed: 11.56s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_470 | 470/512
# ======================================================================
# F1: 0.9550449096343877
# Elapsed: 11.08s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_471 | 471/512
# ======================================================================
# F1: 0.9075532125487417
# Elapsed: 11.70s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_472 | 472/512
# ======================================================================
# F1: 0.8178520692566995
# Elapsed: 11.22s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_473 | 473/512
# ======================================================================
# F1: 0.7345601444013358
# Elapsed: 8.90s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_474 | 474/512
# ======================================================================
# F1: 0.8612632946662814
# Elapsed: 8.98s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_475 | 475/512
# ======================================================================
# F1: 0.8478550875885551
# Elapsed: 8.71s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_476 | 476/512
# ======================================================================
# F1: 0.7239779430375632
# Elapsed: 8.35s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_477 | 477/512
# ======================================================================
# F1: 0.6681617821588791
# Elapsed: 11.85s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_478 | 478/512
# ======================================================================
# F1: 0.833944931417425
# Elapsed: 10.96s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_479 | 479/512
# ======================================================================
# F1: 0.8386810681814865
# Elapsed: 11.48s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_480 | 480/512
# ======================================================================
# F1: 0.43477198956350815
# Elapsed: 11.28s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_481 | 481/512
# ======================================================================
# F1: 0.9314768296283823
# Elapsed: 8.83s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_482 | 482/512
# ======================================================================
# F1: 0.9265252285289103
# Elapsed: 8.49s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_483 | 483/512
# ======================================================================
# F1: 0.9432354712496179
# Elapsed: 9.00s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_484 | 484/512
# ======================================================================
# F1: 0.9278974783377733
# Elapsed: 9.23s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_485 | 485/512
# ======================================================================
# F1: 0.9021747869654888
# Elapsed: 11.48s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_486 | 486/512
# ======================================================================
# F1: 0.9159643359774432
# Elapsed: 11.53s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_487 | 487/512
# ======================================================================
# F1: 0.8849655039320478
# Elapsed: 10.97s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_488 | 488/512
# ======================================================================
# F1: 0.8362619120137232
# Elapsed: 11.10s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_489 | 489/512
# ======================================================================
# F1: 0.9369762940341333
# Elapsed: 8.84s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_490 | 490/512
# ======================================================================
# F1: 0.9385766612655437
# Elapsed: 8.97s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_491 | 491/512
# ======================================================================
# F1: 0.9279584848360051
# Elapsed: 8.62s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_492 | 492/512
# ======================================================================
# F1: 0.9084430467494737
# Elapsed: 8.81s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_493 | 493/512
# ======================================================================
# F1: 0.9291046107943695
# Elapsed: 11.34s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_494 | 494/512
# ======================================================================
# F1: 0.9494247063474225
# Elapsed: 11.49s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_495 | 495/512
# ======================================================================
# F1: 0.9518890784850429
# Elapsed: 11.39s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_496 | 496/512
# ======================================================================
# F1: 0.864319750930871
# Elapsed: 11.39s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_497 | 497/512
# ======================================================================
# F1: 0.9160438912096627
# Elapsed: 8.81s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_498 | 498/512
# ======================================================================
# F1: 0.9099051992629589
# Elapsed: 8.86s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_499 | 499/512
# ======================================================================
# F1: 0.8975252974169106
# Elapsed: 8.65s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_500 | 500/512
# ======================================================================
# F1: 0.8688697347224835
# Elapsed: 8.87s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_501 | 501/512
# ======================================================================
# F1: 0.8406599949544965
# Elapsed: 11.37s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_502 | 502/512
# ======================================================================
# F1: 0.9473243365761469
# Elapsed: 11.38s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_503 | 503/512
# ======================================================================
# F1: 0.910950648777534
# Elapsed: 11.19s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_504 | 504/512
# ======================================================================
# F1: 0.8824572366649498
# Elapsed: 11.37s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_505 | 505/512
# ======================================================================
# F1: 0.7372394108229864
# Elapsed: 8.87s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_506 | 506/512
# ======================================================================
# F1: 0.888521080829998
# Elapsed: 8.85s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_507 | 507/512
# ======================================================================
# F1: 0.8537825652332094
# Elapsed: 8.81s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_508 | 508/512
# ======================================================================
# F1: 0.708494615214977
# Elapsed: 9.02s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_509 | 509/512
# ======================================================================
# F1: 0.6361434304866513
# Elapsed: 11.32s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_510 | 510/512
# ======================================================================
# F1: 0.8493560484685123
# Elapsed: 11.32s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_511 | 511/512
# ======================================================================
# F1: 0.8299085966998554
# Elapsed: 11.30s
#
# ======================================================================
# 🚀 Ejecutando experimento: TRAIN_512 | 512/512
# ======================================================================
# F1: 0.42287599671077813
# Elapsed: 11.34s

# %%
results_df = pd.DataFrame(results).sort_values(
    by=["Test Macro-F1", "Test Balanced Acc", "Test Accuracy"],
    ascending=False
).reset_index(drop=True)

display(
    results_df.style.format({
        "Parámetros": "{:,}",
        "Val Accuracy": "{:.2%}",
        "Val Balanced Acc": "{:.2%}",
        "Val Macro-F1": "{:.2%}",
        "Test Accuracy": "{:.2%}",
        "Test Balanced Acc": "{:.2%}",
        "Test Macro-F1": "{:.2%}",
        "Tiempo (s)": "{:.1f}",
    }).background_gradient(subset=["Test Macro-F1"], cmap="Greens")
)

# %%
import pandas as pd

top_10 = sorted(
    trained_models_tr.items(),
    key=lambda item: item[1]["val_macro_f1"],
    reverse=True
)[:10]

df = pd.DataFrame([
    {
        "rank": i + 1,
        "name": name,
        "val_macro_f1": data["val_macro_f1"],
        "time_sec": data["time"]
    }
    for i, (name, data) in enumerate(top_10)
])

display(
    df.style.format({
        "name": "{}",
        "val_macro_f1": "{:.2%}",
    }).background_gradient(subset=["val_macro_f1"], cmap="Greens")
)
# Out:
# <style type="text/css">
# #T_7b8db_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7b8db_row1_col2 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_7b8db_row2_col2 {
#   background-color: #17813d;
#   color: #f1f1f1;
# }
# #T_7b8db_row3_col2 {
#   background-color: #29914a;
#   color: #f1f1f1;
# }
# #T_7b8db_row4_col2 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_7b8db_row5_col2 {
#   background-color: #2e964d;
#   color: #f1f1f1;
# }
# #T_7b8db_row6_col2 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_7b8db_row7_col2 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_7b8db_row8_col2 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_7b8db_row9_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_7b8db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b8db_level0_col0" class="col_heading level0 col0" >rank</th>
#       <th id="T_7b8db_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_7b8db_level0_col2" class="col_heading level0 col2" >val_macro_f1</th>
#       <th id="T_7b8db_level0_col3" class="col_heading level0 col3" >time_sec</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b8db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b8db_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7b8db_row0_col1" class="data row0 col1" >TRAIN_294</td>
#       <td id="T_7b8db_row0_col2" class="data row0 col2" >97.04%</td>
#       <td id="T_7b8db_row0_col3" class="data row0 col3" >10.656087</td>
#     </tr>
#     <tr>
#       <th id="T_7b8db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b8db_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_7b8db_row1_col1" class="data row1 col1" >TRAIN_462</td>
#       <td id="T_7b8db_row1_col2" class="data row1 col2" >97.00%</td>
#       <td id="T_7b8db_row1_col3" class="data row1 col3" >11.550091</td>
#     </tr>
#     <tr>
#       <th id="T_7b8db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b8db_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7b8db_row2_col1" class="data row2 col1" >TRAIN_262</td>
#       <td id="T_7b8db_row2_col2" class="data row2 col2" >96.85%</td>
#       <td id="T_7b8db_row2_col3" class="data row2 col3" >10.616250</td>
#     </tr>
#     <tr>
#       <th id="T_7b8db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b8db_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_7b8db_row3_col1" class="data row3 col1" >TRAIN_078</td>
#       <td id="T_7b8db_row3_col2" class="data row3 col2" >96.78%</td>
#       <td id="T_7b8db_row3_col3" class="data row3 col3" >10.513235</td>
#     </tr>
#     <tr>
#       <th id="T_7b8db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7b8db_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_7b8db_row4_col1" class="data row4 col1" >TRAIN_270</td>
#       <td id="T_7b8db_row4_col2" class="data row4 col2" >96.77%</td>
#       <td id="T_7b8db_row4_col3" class="data row4 col3" >10.699166</td>
#     </tr>
#     <tr>
#       <th id="T_7b8db_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7b8db_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_7b8db_row5_col1" class="data row5 col1" >TRAIN_166</td>
#       <td id="T_7b8db_row5_col2" class="data row5 col2" >96.77%</td>
#       <td id="T_7b8db_row5_col3" class="data row5 col3" >10.662736</td>
#     </tr>
#     <tr>
#       <th id="T_7b8db_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7b8db_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_7b8db_row6_col1" class="data row6 col1" >TRAIN_422</td>
#       <td id="T_7b8db_row6_col2" class="data row6 col2" >96.33%</td>
#       <td id="T_7b8db_row6_col3" class="data row6 col3" >10.449667</td>
#     </tr>
#     <tr>
#       <th id="T_7b8db_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7b8db_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_7b8db_row7_col1" class="data row7 col1" >TRAIN_006</td>
#       <td id="T_7b8db_row7_col2" class="data row7 col2" >96.29%</td>
#       <td id="T_7b8db_row7_col3" class="data row7 col3" >11.339618</td>
#     </tr>
#     <tr>
#       <th id="T_7b8db_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7b8db_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_7b8db_row8_col1" class="data row8 col1" >TRAIN_238</td>
#       <td id="T_7b8db_row8_col2" class="data row8 col2" >96.12%</td>
#       <td id="T_7b8db_row8_col3" class="data row8 col3" >10.554248</td>
#     </tr>
#     <tr>
#       <th id="T_7b8db_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7b8db_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_7b8db_row9_col1" class="data row9 col1" >TRAIN_175</td>
#       <td id="T_7b8db_row9_col2" class="data row9 col2" >96.12%</td>
#       <td id="T_7b8db_row9_col3" class="data row9 col3" >10.778962</td>
#     </tr>
#   </tbody>
# </table>

# %%
#top_10_names = ['TRAIN_294', 'TRAIN_462', 'TRAIN_262', 'TRAIN_078', 'TRAIN_270', 'TRAIN_166', 'TRAIN_422', 'TRAIN_006', 'TRAIN_238', 'TRAIN_175']

# %%
top_10_names = list(df['name'])
best_experiments_training = list(filter(lambda x: x['name'] in top_10_names, training_experiments))

cnn_architecture_grid = {
    "architecture": [
        {
            "base_channels": [16, 32],
            "kernel_sizes": [3, 3],
            "paddings": [1, 1],
        },
        {
            "base_channels": [32, 64],
            "kernel_sizes": [3, 3],
            "paddings": [1, 1],
        },
        {
            "base_channels": [32, 64, 128],
            "kernel_sizes": [3, 3, 3],
            "paddings": [1, 1, 1],
        },
        {
            "base_channels": [32, 64, 128],
            "kernel_sizes": [5, 3, 3],
            "paddings": [2, 1, 1],
        },
    ],

    "hidden_layers": [
        [],
        [64],
        [128],
        [128, 64],
    ],

    'params': best_experiments_training,
}

architecture_experiments = grid_to_experiments(cnn_architecture_grid, prefix="ARCH")

# %%
best_experiments_training
# Out:
# [{'dropout': 0.0,
#   'weight_decay': 0.0,
#   'learning_rate': 0.01,
#   'augmentation': True,
#   'class_weighted_loss': False,
#   'weighted_sampling': True,
#   'name': 'TRAIN_006'},
#  {'dropout': 0.0,
#   'weight_decay': 0.0001,
#   'learning_rate': 0.003,
#   'augmentation': True,
#   'class_weighted_loss': False,
#   'weighted_sampling': True,
#   'name': 'TRAIN_078'},
#  {'dropout': 0.1,
#   'weight_decay': 1e-05,
#   'learning_rate': 0.01,
#   'augmentation': True,
#   'class_weighted_loss': False,
#   'weighted_sampling': True,
#   'name': 'TRAIN_166'},
#  {'dropout': 0.1,
#   'weight_decay': 1e-05,
#   'learning_rate': 0.003,
#   'augmentation': True,
#   'class_weighted_loss': True,
#   'weighted_sampling': False,
#   'name': 'TRAIN_175'},
#  {'dropout': 0.1,
#   'weight_decay': 0.001,
#   'learning_rate': 0.003,
#   'augmentation': True,
#   'class_weighted_loss': False,
#   'weighted_sampling': True,
#   'name': 'TRAIN_238'},
#  {'dropout': 0.25,
#   'weight_decay': 0.0,
#   'learning_rate': 0.01,
#   'augmentation': True,
#   'class_weighted_loss': False,
#   'weighted_sampling': True,
#   'name': 'TRAIN_262'},
#  {'dropout': 0.25,
#   'weight_decay': 0.0,
#   'learning_rate': 0.003,
#   'augmentation': True,
#   'class_weighted_loss': False,
#   'weighted_sampling': True,
#   'name': 'TRAIN_270'},
#  {'dropout': 0.25,
#   'weight_decay': 1e-05,
#   'learning_rate': 0.01,
#   'augmentation': True,
#   'class_weighted_loss': False,
#   'weighted_sampling': True,
#   'name': 'TRAIN_294'},
#  {'dropout': 0.4,
#   'weight_decay': 1e-05,
#   'learning_rate': 0.01,
#   'augmentation': True,
#   'class_weighted_loss': False,
#   'weighted_sampling': True,
#   'name': 'TRAIN_422'},
#  {'dropout': 0.4,
#   'weight_decay': 0.0001,
#   'learning_rate': 0.003,
#   'augmentation': True,
#   'class_weighted_loss': False,
#   'weighted_sampling': True,
#   'name': 'TRAIN_462'}]

# %%
results_arch = []
trained_models_arch = {}
histories_arch = {}

total = len(architecture_experiments)
for i, exp in enumerate(architecture_experiments, start=1):
    print(f"\n{'='*70}")
    print(f"🚀 Ejecutando experimento: {exp['name']} | {i}/{total}")
    print(f"{'='*70}")

    train_loader, val_loader, test_loader = make_loaders(
        batch_size=CONFIG["batch_size"],
        augmentation=exp['params']["augmentation"],
        weighted_sampling=exp['params']["weighted_sampling"],
        num_workers=CONFIG["num_workers"],
    )

    model = SimpleCNN(
        base_channels=exp['architecture']['base_channels'], 
        kernel_sizes=exp['architecture']['kernel_sizes'], 
        paddings=exp['architecture']['paddings'], 
        hidden_layers=exp['hidden_layers'], 
        dropout=exp['params']['dropout']
    )

    model, history, elapsed, val_macro_f1 = train_model_optim(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        epochs=CONFIG["epochs"],
        lr=exp['params']["learning_rate"],
        weight_decay=exp['params']["weight_decay"],
        class_weighted_loss=exp['params']["class_weighted_loss"],
        early_stopping_patience=CONFIG["early_stopping_patience"],
        device=device,
        model_name=exp['name'],
        verbose=False,
    )
    print(f'F1: {val_macro_f1}')
    print(f'Elapsed: {elapsed:.2f}s')

    trained_models_arch[exp["name"]] = {
        "model": model,
        "val_macro_f1": val_macro_f1,
        'time': elapsed
    }
    histories_arch[exp["name"]] = history
# Out:
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_001 | 1/160
# ======================================================================
# F1: 0.947999832729814
# Elapsed: 12.67s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_002 | 2/160
# ======================================================================
# F1: 0.9428114230983766
# Elapsed: 13.29s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_003 | 3/160
# ======================================================================
# F1: 0.960851989581656
# Elapsed: 12.35s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_004 | 4/160
# ======================================================================
# F1: 0.9471036326746297
# Elapsed: 12.56s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_005 | 5/160
# ======================================================================
# F1: 0.9612496724571267
# Elapsed: 12.34s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_006 | 6/160
# ======================================================================
# F1: 0.9268437507484937
# Elapsed: 12.72s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_007 | 7/160
# ======================================================================
# F1: 0.9448373902872309
# Elapsed: 12.89s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_008 | 8/160
# ======================================================================
# F1: 0.9590091194723621
# Elapsed: 12.36s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_009 | 9/160
# ======================================================================
# F1: 0.9517118160848221
# Elapsed: 11.93s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_010 | 10/160
# ======================================================================
# F1: 0.9603322780102184
# Elapsed: 13.12s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_011 | 11/160
# ======================================================================
# F1: 0.95451972220035
# Elapsed: 13.07s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_012 | 12/160
# ======================================================================
# F1: 0.9501370357305179
# Elapsed: 13.17s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_013 | 13/160
# ======================================================================
# F1: 0.9615188476634058
# Elapsed: 13.26s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_014 | 14/160
# ======================================================================
# F1: 0.9472393168208088
# Elapsed: 13.15s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_015 | 15/160
# ======================================================================
# F1: 0.9377628131590073
# Elapsed: 13.15s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_016 | 16/160
# ======================================================================
# F1: 0.9666995090910566
# Elapsed: 13.10s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_017 | 17/160
# ======================================================================
# F1: 0.9588965385395323
# Elapsed: 13.16s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_018 | 18/160
# ======================================================================
# F1: 0.9607800232803182
# Elapsed: 13.18s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_019 | 19/160
# ======================================================================
# F1: 0.9645406276295828
# Elapsed: 13.09s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_020 | 20/160
# ======================================================================
# F1: 0.9541539676206124
# Elapsed: 12.68s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_021 | 21/160
# ======================================================================
# F1: 0.9501284650041061
# Elapsed: 12.50s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_022 | 22/160
# ======================================================================
# F1: 0.9563791627414886
# Elapsed: 12.73s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_023 | 23/160
# ======================================================================
# F1: 0.9599104807313431
# Elapsed: 11.86s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_024 | 24/160
# ======================================================================
# F1: 0.9487950910795941
# Elapsed: 12.16s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_025 | 25/160
# ======================================================================
# F1: 0.9544685686906431
# Elapsed: 11.87s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_026 | 26/160
# ======================================================================
# F1: 0.8754665718331722
# Elapsed: 11.89s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_027 | 27/160
# ======================================================================
# F1: 0.9680422420696655
# Elapsed: 12.47s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_028 | 28/160
# ======================================================================
# F1: 0.9489358548642386
# Elapsed: 11.67s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_029 | 29/160
# ======================================================================
# F1: 0.9572313724021365
# Elapsed: 11.39s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_030 | 30/160
# ======================================================================
# F1: 0.9501827324041173
# Elapsed: 11.99s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_031 | 31/160
# ======================================================================
# F1: 0.9539361550862926
# Elapsed: 11.70s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_032 | 32/160
# ======================================================================
# F1: 0.978721322369106
# Elapsed: 11.52s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_033 | 33/160
# ======================================================================
# F1: 0.9495262249792107
# Elapsed: 12.61s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_034 | 34/160
# ======================================================================
# F1: 0.9575078978404651
# Elapsed: 12.73s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_035 | 35/160
# ======================================================================
# F1: 0.9476931963994529
# Elapsed: 12.54s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_036 | 36/160
# ======================================================================
# F1: 0.9551432172344085
# Elapsed: 11.42s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_037 | 37/160
# ======================================================================
# F1: 0.949079490506058
# Elapsed: 11.32s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_038 | 38/160
# ======================================================================
# F1: 0.8086110431052791
# Elapsed: 11.22s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_039 | 39/160
# ======================================================================
# F1: 0.9389580915565496
# Elapsed: 11.13s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_040 | 40/160
# ======================================================================
# F1: 0.9537986509941174
# Elapsed: 11.86s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_041 | 41/160
# ======================================================================
# F1: 0.9424428270698005
# Elapsed: 11.86s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_042 | 42/160
# ======================================================================
# F1: 0.9589973080479783
# Elapsed: 11.79s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_043 | 43/160
# ======================================================================
# F1: 0.9304603150386146
# Elapsed: 11.46s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_044 | 44/160
# ======================================================================
# F1: 0.9538753189930651
# Elapsed: 11.72s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_045 | 45/160
# ======================================================================
# F1: 0.9533205380394433
# Elapsed: 11.54s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_046 | 46/160
# ======================================================================
# F1: 0.9040775334235764
# Elapsed: 11.70s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_047 | 47/160
# ======================================================================
# F1: 0.9481390858908499
# Elapsed: 11.69s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_048 | 48/160
# ======================================================================
# F1: 0.9122767460695753
# Elapsed: 11.93s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_049 | 49/160
# ======================================================================
# F1: 0.9403984155108592
# Elapsed: 11.60s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_050 | 50/160
# ======================================================================
# F1: 0.9471050099147341
# Elapsed: 11.61s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_051 | 51/160
# ======================================================================
# F1: 0.9528567386227824
# Elapsed: 11.76s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_052 | 52/160
# ======================================================================
# F1: 0.9386430523626652
# Elapsed: 11.83s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_053 | 53/160
# ======================================================================
# F1: 0.043243243243243246
# Elapsed: 11.52s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_054 | 54/160
# ======================================================================
# F1: 0.9455639557904199
# Elapsed: 11.83s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_055 | 55/160
# ======================================================================
# F1: 0.965005935073374
# Elapsed: 11.53s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_056 | 56/160
# ======================================================================
# F1: 0.895771357673644
# Elapsed: 11.68s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_057 | 57/160
# ======================================================================
# F1: 0.9426435181806128
# Elapsed: 11.63s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_058 | 58/160
# ======================================================================
# F1: 0.8060289529891029
# Elapsed: 11.49s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_059 | 59/160
# ======================================================================
# F1: 0.8853337696727628
# Elapsed: 11.76s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_060 | 60/160
# ======================================================================
# F1: 0.9537852790765117
# Elapsed: 11.43s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_061 | 61/160
# ======================================================================
# F1: 0.043243243243243246
# Elapsed: 11.37s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_062 | 62/160
# ======================================================================
# F1: 0.9692432293293651
# Elapsed: 11.84s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_063 | 63/160
# ======================================================================
# F1: 0.8657138431789535
# Elapsed: 11.84s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_064 | 64/160
# ======================================================================
# F1: 0.9624547943192132
# Elapsed: 11.81s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_065 | 65/160
# ======================================================================
# F1: 0.9592261571867555
# Elapsed: 11.77s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_066 | 66/160
# ======================================================================
# F1: 0.9636758544706202
# Elapsed: 11.95s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_067 | 67/160
# ======================================================================
# F1: 0.960556701219681
# Elapsed: 11.69s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_068 | 68/160
# ======================================================================
# F1: 0.9426125752558118
# Elapsed: 11.90s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_069 | 69/160
# ======================================================================
# F1: 0.8520766018093278
# Elapsed: 12.01s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_070 | 70/160
# ======================================================================
# F1: 0.9575980287751509
# Elapsed: 11.93s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_071 | 71/160
# ======================================================================
# F1: 0.043243243243243246
# Elapsed: 11.73s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_072 | 72/160
# ======================================================================
# F1: 0.9520175230835163
# Elapsed: 11.76s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_073 | 73/160
# ======================================================================
# F1: 0.9382179548160933
# Elapsed: 12.12s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_074 | 74/160
# ======================================================================
# F1: 0.9522963228103707
# Elapsed: 11.71s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_075 | 75/160
# ======================================================================
# F1: 0.9622449569485545
# Elapsed: 11.67s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_076 | 76/160
# ======================================================================
# F1: 0.9326726852031214
# Elapsed: 12.01s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_077 | 77/160
# ======================================================================
# F1: 0.9696737416357669
# Elapsed: 11.41s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_078 | 78/160
# ======================================================================
# F1: 0.043243243243243246
# Elapsed: 11.51s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_079 | 79/160
# ======================================================================
# F1: 0.9093377490812043
# Elapsed: 11.60s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_080 | 80/160
# ======================================================================
# F1: 0.9605409934770167
# Elapsed: 11.66s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_081 | 81/160
# ======================================================================
# F1: 0.9341930825305361
# Elapsed: 12.03s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_082 | 82/160
# ======================================================================
# F1: 0.9772152557419302
# Elapsed: 12.00s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_083 | 83/160
# ======================================================================
# F1: 0.9018780479585201
# Elapsed: 11.90s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_084 | 84/160
# ======================================================================
# F1: 0.9530716872928311
# Elapsed: 11.97s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_085 | 85/160
# ======================================================================
# F1: 0.9585007627584392
# Elapsed: 12.01s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_086 | 86/160
# ======================================================================
# F1: 0.8941774996850118
# Elapsed: 11.73s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_087 | 87/160
# ======================================================================
# F1: 0.9559701707013204
# Elapsed: 11.96s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_088 | 88/160
# ======================================================================
# F1: 0.9530656951564354
# Elapsed: 11.85s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_089 | 89/160
# ======================================================================
# F1: 0.8757408138709731
# Elapsed: 11.85s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_090 | 90/160
# ======================================================================
# F1: 0.9494928409348848
# Elapsed: 11.93s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_091 | 91/160
# ======================================================================
# F1: 0.043243243243243246
# Elapsed: 11.68s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_092 | 92/160
# ======================================================================
# F1: 0.9645958916741334
# Elapsed: 11.97s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_093 | 93/160
# ======================================================================
# F1: 0.9379251770623747
# Elapsed: 11.79s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_094 | 94/160
# ======================================================================
# F1: 0.9472496581645977
# Elapsed: 11.66s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_095 | 95/160
# ======================================================================
# F1: 0.9532176276575901
# Elapsed: 11.72s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_096 | 96/160
# ======================================================================
# F1: 0.9483974527298002
# Elapsed: 11.80s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_097 | 97/160
# ======================================================================
# F1: 0.9566516644048508
# Elapsed: 11.95s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_098 | 98/160
# ======================================================================
# F1: 0.926863314413103
# Elapsed: 11.95s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_099 | 99/160
# ======================================================================
# F1: 0.8767565547671656
# Elapsed: 12.22s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_100 | 100/160
# ======================================================================
# F1: 0.946464847202806
# Elapsed: 12.16s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_101 | 101/160
# ======================================================================
# F1: 0.9469306131578488
# Elapsed: 11.90s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_102 | 102/160
# ======================================================================
# F1: 0.9621952922983045
# Elapsed: 11.86s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_103 | 103/160
# ======================================================================
# F1: 0.9241228801248192
# Elapsed: 11.96s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_104 | 104/160
# ======================================================================
# F1: 0.9648712820440796
# Elapsed: 11.96s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_105 | 105/160
# ======================================================================
# F1: 0.9671784062664746
# Elapsed: 11.85s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_106 | 106/160
# ======================================================================
# F1: 0.043243243243243246
# Elapsed: 12.11s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_107 | 107/160
# ======================================================================
# F1: 0.9603925380881364
# Elapsed: 12.49s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_108 | 108/160
# ======================================================================
# F1: 0.9272740668554118
# Elapsed: 12.37s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_109 | 109/160
# ======================================================================
# F1: 0.043243243243243246
# Elapsed: 11.92s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_110 | 110/160
# ======================================================================
# F1: 0.9563009990716997
# Elapsed: 11.88s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_111 | 111/160
# ======================================================================
# F1: 0.9273794457054472
# Elapsed: 12.06s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_112 | 112/160
# ======================================================================
# F1: 0.9509913383498745
# Elapsed: 11.80s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_113 | 113/160
# ======================================================================
# F1: 0.929651412917786
# Elapsed: 11.89s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_114 | 114/160
# ======================================================================
# F1: 0.949506359642289
# Elapsed: 11.85s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_115 | 115/160
# ======================================================================
# F1: 0.9452197163994246
# Elapsed: 11.86s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_116 | 116/160
# ======================================================================
# F1: 0.043243243243243246
# Elapsed: 12.01s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_117 | 117/160
# ======================================================================
# F1: 0.9658077661207413
# Elapsed: 11.93s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_118 | 118/160
# ======================================================================
# F1: 0.043243243243243246
# Elapsed: 11.85s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_119 | 119/160
# ======================================================================
# F1: 0.7802400999980211
# Elapsed: 11.68s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_120 | 120/160
# ======================================================================
# F1: 0.9486337422919293
# Elapsed: 12.02s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_121 | 121/160
# ======================================================================
# F1: 0.9265606288495668
# Elapsed: 11.95s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_122 | 122/160
# ======================================================================
# F1: 0.9598726172201781
# Elapsed: 11.94s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_123 | 123/160
# ======================================================================
# F1: 0.9399044338556578
# Elapsed: 11.84s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_124 | 124/160
# ======================================================================
# F1: 0.9712323509197424
# Elapsed: 11.93s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_125 | 125/160
# ======================================================================
# F1: 0.9638758375255223
# Elapsed: 12.14s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_126 | 126/160
# ======================================================================
# F1: 0.9600044881722211
# Elapsed: 11.89s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_127 | 127/160
# ======================================================================
# F1: 0.9751908880285983
# Elapsed: 11.76s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_128 | 128/160
# ======================================================================
# F1: 0.9084683022389448
# Elapsed: 12.04s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_129 | 129/160
# ======================================================================
# F1: 0.9637817019667156
# Elapsed: 12.11s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_130 | 130/160
# ======================================================================
# F1: 0.9623475053498423
# Elapsed: 12.00s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_131 | 131/160
# ======================================================================
# F1: 0.926417874815679
# Elapsed: 12.16s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_132 | 132/160
# ======================================================================
# F1: 0.956612016617815
# Elapsed: 11.94s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_133 | 133/160
# ======================================================================
# F1: 0.9385546060265073
# Elapsed: 11.92s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_134 | 134/160
# ======================================================================
# F1: 0.9540519501572607
# Elapsed: 11.90s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_135 | 135/160
# ======================================================================
# F1: 0.9619218107824791
# Elapsed: 12.01s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_136 | 136/160
# ======================================================================
# F1: 0.8913340821428098
# Elapsed: 12.03s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_137 | 137/160
# ======================================================================
# F1: 0.960589575231382
# Elapsed: 12.13s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_138 | 138/160
# ======================================================================
# F1: 0.912111144889223
# Elapsed: 11.95s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_139 | 139/160
# ======================================================================
# F1: 0.9316475088185767
# Elapsed: 11.83s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_140 | 140/160
# ======================================================================
# F1: 0.950563869795548
# Elapsed: 11.85s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_141 | 141/160
# ======================================================================
# F1: 0.9182149375138895
# Elapsed: 12.26s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_142 | 142/160
# ======================================================================
# F1: 0.9684224216017927
# Elapsed: 11.79s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_143 | 143/160
# ======================================================================
# F1: 0.9003793776321922
# Elapsed: 12.00s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_144 | 144/160
# ======================================================================
# F1: 0.9365387423582237
# Elapsed: 11.96s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_145 | 145/160
# ======================================================================
# F1: 0.968812452221022
# Elapsed: 11.92s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_146 | 146/160
# ======================================================================
# F1: 0.9252207556858432
# Elapsed: 12.30s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_147 | 147/160
# ======================================================================
# F1: 0.9689218700028615
# Elapsed: 11.91s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_148 | 148/160
# ======================================================================
# F1: 0.9428499216648836
# Elapsed: 11.75s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_149 | 149/160
# ======================================================================
# F1: 0.9003062105307308
# Elapsed: 12.06s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_150 | 150/160
# ======================================================================
# F1: 0.9642900205545978
# Elapsed: 12.13s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_151 | 151/160
# ======================================================================
# F1: 0.8723313384354967
# Elapsed: 11.84s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_152 | 152/160
# ======================================================================
# F1: 0.948964963079109
# Elapsed: 12.13s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_153 | 153/160
# ======================================================================
# F1: 0.043243243243243246
# Elapsed: 11.93s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_154 | 154/160
# ======================================================================
# F1: 0.9556237874045056
# Elapsed: 11.94s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_155 | 155/160
# ======================================================================
# F1: 0.9454879133421894
# Elapsed: 12.04s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_156 | 156/160
# ======================================================================
# F1: 0.9081243509114889
# Elapsed: 12.18s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_157 | 157/160
# ======================================================================
# F1: 0.970400594556045
# Elapsed: 12.32s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_158 | 158/160
# ======================================================================
# F1: 0.9070184744125624
# Elapsed: 11.84s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_159 | 159/160
# ======================================================================
# F1: 0.9008989815497086
# Elapsed: 12.22s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_160 | 160/160
# ======================================================================
# F1: 0.9697021946426156
# Elapsed: 12.15s

# %%
top_5 = sorted(
    trained_models_arch.items(),
    key=lambda item: item[1]["val_macro_f1"],
    reverse=True
)[:5]

df_2 = pd.DataFrame([
    {
        "rank": i + 1,
        "name": name,
        "val_macro_f1": data["val_macro_f1"],
        "time_sec": data["time"]
    }
    for i, (name, data) in enumerate(top_5)
])

display(
    df_2.style.format({
        "name": "{}",
        "val_macro_f1": "{:.2%}",
    }).background_gradient(subset=["val_macro_f1"], cmap="Greens")
)
# Out:
# <style type="text/css">
# #T_106f6_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_106f6_row1_col2 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_106f6_row2_col2 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_106f6_row3_col2 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_106f6_row4_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_106f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_106f6_level0_col0" class="col_heading level0 col0" >rank</th>
#       <th id="T_106f6_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_106f6_level0_col2" class="col_heading level0 col2" >val_macro_f1</th>
#       <th id="T_106f6_level0_col3" class="col_heading level0 col3" >time_sec</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_106f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_106f6_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_106f6_row0_col1" class="data row0 col1" >ARCH_032</td>
#       <td id="T_106f6_row0_col2" class="data row0 col2" >97.87%</td>
#       <td id="T_106f6_row0_col3" class="data row0 col3" >11.521438</td>
#     </tr>
#     <tr>
#       <th id="T_106f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_106f6_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_106f6_row1_col1" class="data row1 col1" >ARCH_082</td>
#       <td id="T_106f6_row1_col2" class="data row1 col2" >97.72%</td>
#       <td id="T_106f6_row1_col3" class="data row1 col3" >12.000453</td>
#     </tr>
#     <tr>
#       <th id="T_106f6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_106f6_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_106f6_row2_col1" class="data row2 col1" >ARCH_127</td>
#       <td id="T_106f6_row2_col2" class="data row2 col2" >97.52%</td>
#       <td id="T_106f6_row2_col3" class="data row2 col3" >11.757653</td>
#     </tr>
#     <tr>
#       <th id="T_106f6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_106f6_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_106f6_row3_col1" class="data row3 col1" >ARCH_124</td>
#       <td id="T_106f6_row3_col2" class="data row3 col2" >97.12%</td>
#       <td id="T_106f6_row3_col3" class="data row3 col3" >11.926361</td>
#     </tr>
#     <tr>
#       <th id="T_106f6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_106f6_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_106f6_row4_col1" class="data row4 col1" >ARCH_157</td>
#       <td id="T_106f6_row4_col2" class="data row4 col2" >97.04%</td>
#       <td id="T_106f6_row4_col3" class="data row4 col3" >12.322090</td>
#     </tr>
#   </tbody>
# </table>

# %%
top_5_names = list(df_2['name'])
best_experiments_arch = list(filter(lambda x: x['name'] in top_5_names, architecture_experiments))
best_experiments_arch
# Out:
# [{'architecture': {'base_channels': [16, 32],
#    'kernel_sizes': [3, 3],
#    'paddings': [1, 1]},
#   'hidden_layers': [128, 64],
#   'params': {'dropout': 0.0,
#    'weight_decay': 0.0001,
#    'learning_rate': 0.003,
#    'augmentation': True,
#    'class_weighted_loss': False,
#    'weighted_sampling': True,
#    'name': 'TRAIN_078'},
#   'name': 'ARCH_032'},
#  {'architecture': {'base_channels': [32, 64, 128],
#    'kernel_sizes': [3, 3, 3],
#    'paddings': [1, 1, 1]},
#   'hidden_layers': [],
#   'params': {'dropout': 0.0,
#    'weight_decay': 0.0001,
#    'learning_rate': 0.003,
#    'augmentation': True,
#    'class_weighted_loss': False,
#    'weighted_sampling': True,
#    'name': 'TRAIN_078'},
#   'name': 'ARCH_082'},
#  {'architecture': {'base_channels': [32, 64, 128],
#    'kernel_sizes': [5, 3, 3],
#    'paddings': [2, 1, 1]},
#   'hidden_layers': [],
#   'params': {'dropout': 0.1,
#    'weight_decay': 1e-05,
#    'learning_rate': 0.003,
#    'augmentation': True,
#    'class_weighted_loss': True,
#    'weighted_sampling': False,
#    'name': 'TRAIN_175'},
#   'name': 'ARCH_124'},
#  {'architecture': {'base_channels': [32, 64, 128],
#    'kernel_sizes': [5, 3, 3],
#    'paddings': [2, 1, 1]},
#   'hidden_layers': [],
#   'params': {'dropout': 0.25,
#    'weight_decay': 0.0,
#    'learning_rate': 0.003,
#    'augmentation': True,
#    'class_weighted_loss': False,
#    'weighted_sampling': True,
#    'name': 'TRAIN_270'},
#   'name': 'ARCH_127'},
#  {'architecture': {'base_channels': [32, 64, 128],
#    'kernel_sizes': [5, 3, 3],
#    'paddings': [2, 1, 1]},
#   'hidden_layers': [128, 64],
#   'params': {'dropout': 0.25,
#    'weight_decay': 0.0,
#    'learning_rate': 0.003,
#    'augmentation': True,
#    'class_weighted_loss': False,
#    'weighted_sampling': True,
#    'name': 'TRAIN_270'},
#   'name': 'ARCH_157'}]

# %%
results_final = []
trained_models_final = {}
histories_final = {}

total = len(best_experiments_arch)
for i, exp in enumerate(best_experiments_arch, start=1):
    print(f"\n{'='*70}")
    print(f"🚀 Ejecutando experimento: {exp['name']} | {i}/{total}")
    print(f"{'='*70}")

    train_loader, val_loader, test_loader = make_loaders(
        batch_size=CONFIG["batch_size"],
        augmentation=exp['params']["augmentation"],
        weighted_sampling=exp['params']["weighted_sampling"],
        num_workers=CONFIG["num_workers"],
    )

    model = SimpleCNN(
        base_channels=exp['architecture']['base_channels'], 
        kernel_sizes=exp['architecture']['kernel_sizes'], 
        paddings=exp['architecture']['paddings'], 
        hidden_layers=exp['hidden_layers'], 
        dropout=exp['params']['dropout'],
        batch_norm=True
    )

    model, history, elapsed, val_macro_f1 = train_model_optim(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        epochs=100,
        lr=exp['params']["learning_rate"],
        weight_decay=exp['params']["weight_decay"],
        class_weighted_loss=exp['params']["class_weighted_loss"],
        early_stopping_patience=CONFIG["early_stopping_patience"],
        device=device,
        model_name=exp['name'],
        verbose=True,
    )

    val_preds, val_true = collect_predictions(model, val_loader, device)
    test_preds, test_true = collect_predictions(model, test_loader, device)

    val_metrics = compute_metrics(val_true, val_preds)
    test_metrics = compute_metrics(test_true, test_preds)

    print(f'F1: {val_macro_f1}')
    print(f'Elapsed: {elapsed:.2f}s')

    trained_models_final[exp["name"]] = {
        "model": model,
        "val_preds": val_preds,
        "val_true": val_true,
        "test_preds": test_preds,
        "test_true": test_true,
    }
    
    histories_final[exp["name"]] = history

    results_final.append({
        "Experimento": exp["name"].replace("_", " "),
        "Modelo": 'CNN',
        "Parámetros": count_parameters(model),
        'Channels': exp['architecture']['base_channels'],
        'Hidden Layers': exp['hidden_layers'],
        "Augmentation": exp['params']["augmentation"],
        "ClassWeightedLoss": exp['params']["class_weighted_loss"],
        'weighted_sampling': exp['params']['weighted_sampling'],
        "Val Accuracy": val_metrics["accuracy"],
        "Val Balanced Acc": val_metrics["balanced_accuracy"],
        "Val Macro-F1": val_metrics["macro_f1"],
        "Test Accuracy": test_metrics["accuracy"],
        "Test Balanced Acc": test_metrics["balanced_accuracy"],
        "Test Macro-F1": test_metrics["macro_f1"],
        "Tiempo (s)": elapsed,
    })
# Out:
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_032 | 1/5
# ======================================================================
#
# ============================================================
#  Entrenando: ARCH_032
#  Parámetros: 214,634
#  Épocas: 100 | LR: 0.003 | Weight Decay: 0.0001
# ============================================================
#   Época   1/100  |  Train Loss: 2.0690  Macro-F1: 24.80%  |  Val Loss: 1.7709  Macro-F1: 51.50%
#   Época   5/100  |  Train Loss: 0.5160  Macro-F1: 83.48%  |  Val Loss: 0.3393  Macro-F1: 82.01%
#   Época  10/100  |  Train Loss: 0.2124  Macro-F1: 93.76%  |  Val Loss: 0.1413  Macro-F1: 91.21%
#   Época  15/100  |  Train Loss: 0.1429  Macro-F1: 95.24%  |  Val Loss: 0.1466  Macro-F1: 93.63%
#   Época  20/100  |  Train Loss: 0.1336  Macro-F1: 95.66%  |  Val Loss: 0.1126  Macro-F1: 93.55%
#   Época  25/100  |  Train Loss: 0.0825  Macro-F1: 97.20%  |  Val Loss: 0.0891  Macro-F1: 94.53%
#   Época  30/100  |  Train Loss: 0.0768  Macro-F1: 97.47%  |  Val Loss: 0.1036  Macro-F1: 95.65%
#   Época  35/100  |  Train Loss: 0.0816  Macro-F1: 97.40%  |  Val Loss: 0.0839  Macro-F1: 95.90%
#   Época  40/100  |  Train Loss: 0.0573  Macro-F1: 98.08%  |  Val Loss: 0.0803  Macro-F1: 94.85%
#   Época  45/100  |  Train Loss: 0.0457  Macro-F1: 98.56%  |  Val Loss: 0.0725  Macro-F1: 94.96%
#   Época  50/100  |  Train Loss: 0.0362  Macro-F1: 99.01%  |  Val Loss: 0.0845  Macro-F1: 96.40%
#   Época  55/100  |  Train Loss: 0.0482  Macro-F1: 98.60%  |  Val Loss: 0.0875  Macro-F1: 94.24%
#   Época  60/100  |  Train Loss: 0.0283  Macro-F1: 99.09%  |  Val Loss: 0.0952  Macro-F1: 94.69%
#   Época  65/100  |  Train Loss: 0.0354  Macro-F1: 98.72%  |  Val Loss: 0.0796  Macro-F1: 95.27%
# Entrenamiento detenido en la época 66
# F1: 0.9730168207922875
# Elapsed: 30.82s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_082 | 2/5
# ======================================================================
#
# ============================================================
#  Entrenando: ARCH_082
#  Parámetros: 104,650
#  Épocas: 100 | LR: 0.003 | Weight Decay: 0.0001
# ============================================================
#   Época   1/100  |  Train Loss: 2.5052  Macro-F1: 30.65%  |  Val Loss: 1.4232  Macro-F1: 34.32%
#   Época   5/100  |  Train Loss: 0.3490  Macro-F1: 89.71%  |  Val Loss: 0.1826  Macro-F1: 90.85%
#   Época  10/100  |  Train Loss: 0.1518  Macro-F1: 95.77%  |  Val Loss: 0.1323  Macro-F1: 94.80%
#   Época  15/100  |  Train Loss: 0.0855  Macro-F1: 98.18%  |  Val Loss: 0.0976  Macro-F1: 95.65%
#   Época  20/100  |  Train Loss: 0.0691  Macro-F1: 98.15%  |  Val Loss: 0.0948  Macro-F1: 96.51%
#   Época  25/100  |  Train Loss: 0.0505  Macro-F1: 98.71%  |  Val Loss: 0.0701  Macro-F1: 97.63%
#   Época  30/100  |  Train Loss: 0.0437  Macro-F1: 98.78%  |  Val Loss: 0.0474  Macro-F1: 98.24%
#   Época  35/100  |  Train Loss: 0.0482  Macro-F1: 98.89%  |  Val Loss: 0.0567  Macro-F1: 96.87%
#   Época  40/100  |  Train Loss: 0.0332  Macro-F1: 99.26%  |  Val Loss: 0.0426  Macro-F1: 99.22%
#   Época  45/100  |  Train Loss: 0.0206  Macro-F1: 99.74%  |  Val Loss: 0.0494  Macro-F1: 97.66%
#   Época  50/100  |  Train Loss: 0.0251  Macro-F1: 99.22%  |  Val Loss: 0.0644  Macro-F1: 97.43%
# Entrenamiento detenido en la época 52
# F1: 0.9931972308864443
# Elapsed: 25.71s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_124 | 3/5
# ======================================================================
#
# ============================================================
#  Entrenando: ARCH_124
#  Parámetros: 105,162
#  Épocas: 100 | LR: 0.003 | Weight Decay: 1e-05
# ============================================================
#   Época   1/100  |  Train Loss: 2.9416  Macro-F1: 17.95%  |  Val Loss: 2.2299  Macro-F1: 21.61%
#   Época   5/100  |  Train Loss: 0.4835  Macro-F1: 80.55%  |  Val Loss: 0.6136  Macro-F1: 79.46%
#   Época  10/100  |  Train Loss: 0.2031  Macro-F1: 91.10%  |  Val Loss: 0.1552  Macro-F1: 93.52%
#   Época  15/100  |  Train Loss: 0.1479  Macro-F1: 92.05%  |  Val Loss: 0.1301  Macro-F1: 95.22%
#   Época  20/100  |  Train Loss: 0.0962  Macro-F1: 95.51%  |  Val Loss: 0.0700  Macro-F1: 98.27%
#   Época  25/100  |  Train Loss: 0.0835  Macro-F1: 94.18%  |  Val Loss: 0.0984  Macro-F1: 92.06%
#   Época  30/100  |  Train Loss: 0.0714  Macro-F1: 96.65%  |  Val Loss: 0.0480  Macro-F1: 98.85%
#   Época  35/100  |  Train Loss: 0.0467  Macro-F1: 98.04%  |  Val Loss: 0.0758  Macro-F1: 97.33%
# Entrenamiento detenido en la época 38
# F1: 0.9898153655605014
# Elapsed: 18.22s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_127 | 4/5
# ======================================================================
#
# ============================================================
#  Entrenando: ARCH_127
#  Parámetros: 105,162
#  Épocas: 100 | LR: 0.003 | Weight Decay: 0.0
# ============================================================
#   Época   1/100  |  Train Loss: 2.9447  Macro-F1: 24.37%  |  Val Loss: 2.1430  Macro-F1: 26.55%
#   Época   5/100  |  Train Loss: 0.4213  Macro-F1: 88.64%  |  Val Loss: 0.2103  Macro-F1: 88.25%
#   Época  10/100  |  Train Loss: 0.1687  Macro-F1: 95.30%  |  Val Loss: 0.1523  Macro-F1: 92.55%
#   Época  15/100  |  Train Loss: 0.1193  Macro-F1: 96.53%  |  Val Loss: 0.0939  Macro-F1: 96.47%
#   Época  20/100  |  Train Loss: 0.0725  Macro-F1: 98.32%  |  Val Loss: 0.0747  Macro-F1: 97.82%
#   Época  25/100  |  Train Loss: 0.0690  Macro-F1: 98.16%  |  Val Loss: 0.0666  Macro-F1: 96.73%
#   Época  30/100  |  Train Loss: 0.0489  Macro-F1: 98.59%  |  Val Loss: 0.0609  Macro-F1: 97.28%
#   Época  35/100  |  Train Loss: 0.0448  Macro-F1: 98.76%  |  Val Loss: 0.0741  Macro-F1: 96.58%
#   Época  40/100  |  Train Loss: 0.0273  Macro-F1: 99.50%  |  Val Loss: 0.0640  Macro-F1: 95.96%
#   Época  45/100  |  Train Loss: 0.0285  Macro-F1: 99.37%  |  Val Loss: 0.0594  Macro-F1: 97.08%
#   Época  50/100  |  Train Loss: 0.0201  Macro-F1: 99.39%  |  Val Loss: 0.0343  Macro-F1: 98.95%
#   Época  55/100  |  Train Loss: 0.0196  Macro-F1: 99.43%  |  Val Loss: 0.0385  Macro-F1: 98.23%
#   Época  60/100  |  Train Loss: 0.0186  Macro-F1: 99.61%  |  Val Loss: 0.0244  Macro-F1: 98.27%
#   Época  65/100  |  Train Loss: 0.0190  Macro-F1: 99.36%  |  Val Loss: 0.0297  Macro-F1: 98.41%
# Entrenamiento detenido en la época 65
# F1: 0.989460632948638
# Elapsed: 32.10s
#
# ======================================================================
# 🚀 Ejecutando experimento: ARCH_157 | 5/5
# ======================================================================
#
# ============================================================
#  Entrenando: ARCH_157
#  Parámetros: 250,122
#  Épocas: 100 | LR: 0.003 | Weight Decay: 0.0
# ============================================================
#   Época   1/100  |  Train Loss: 2.2521  Macro-F1: 14.15%  |  Val Loss: 1.9882  Macro-F1: 35.47%
#   Época   5/100  |  Train Loss: 0.6638  Macro-F1: 79.08%  |  Val Loss: 0.2731  Macro-F1: 82.20%
#   Época  10/100  |  Train Loss: 0.2220  Macro-F1: 93.06%  |  Val Loss: 0.1399  Macro-F1: 93.47%
#   Época  15/100  |  Train Loss: 0.1703  Macro-F1: 94.81%  |  Val Loss: 0.1321  Macro-F1: 95.17%
#   Época  20/100  |  Train Loss: 0.1253  Macro-F1: 96.11%  |  Val Loss: 0.1052  Macro-F1: 95.86%
#   Época  25/100  |  Train Loss: 0.0839  Macro-F1: 97.28%  |  Val Loss: 0.0707  Macro-F1: 97.08%
#   Época  30/100  |  Train Loss: 0.0773  Macro-F1: 97.86%  |  Val Loss: 0.0657  Macro-F1: 96.38%
#   Época  35/100  |  Train Loss: 0.0645  Macro-F1: 98.07%  |  Val Loss: 0.0511  Macro-F1: 98.27%
#   Época  40/100  |  Train Loss: 0.0436  Macro-F1: 98.62%  |  Val Loss: 0.0827  Macro-F1: 96.23%
#   Época  45/100  |  Train Loss: 0.0597  Macro-F1: 98.27%  |  Val Loss: 0.0639  Macro-F1: 96.31%
#   Época  50/100  |  Train Loss: 0.0681  Macro-F1: 98.08%  |  Val Loss: 0.0664  Macro-F1: 96.11%
# Entrenamiento detenido en la época 51
# F1: 0.9840459768598784
# Elapsed: 24.95s

# %%
results_df = pd.DataFrame(results_final).sort_values(
    by=["Test Macro-F1"],
    ascending=False
).reset_index(drop=True)

display(
    results_df.style.format({
        "Parámetros": "{:,}",
        "Val Macro-F1": "{:.2%}",
        "Test Macro-F1": "{:.2%}",
        "Tiempo (s)": "{:.1f}",
    }).background_gradient(subset=["Test Macro-F1"], cmap="Greens")
)
# Out:
# <style type="text/css">
# #T_7e193_row0_col13 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7e193_row1_col13 {
#   background-color: #2c944c;
#   color: #f1f1f1;
# }
# #T_7e193_row2_col13 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_7e193_row3_col13 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_7e193_row4_col13 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_7e193">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e193_level0_col0" class="col_heading level0 col0" >Experimento</th>
#       <th id="T_7e193_level0_col1" class="col_heading level0 col1" >Modelo</th>
#       <th id="T_7e193_level0_col2" class="col_heading level0 col2" >Parámetros</th>
#       <th id="T_7e193_level0_col3" class="col_heading level0 col3" >Channels</th>
#       <th id="T_7e193_level0_col4" class="col_heading level0 col4" >Hidden Layers</th>
#       <th id="T_7e193_level0_col5" class="col_heading level0 col5" >Augmentation</th>
#       <th id="T_7e193_level0_col6" class="col_heading level0 col6" >ClassWeightedLoss</th>
#       <th id="T_7e193_level0_col7" class="col_heading level0 col7" >weighted_sampling</th>
#       <th id="T_7e193_level0_col8" class="col_heading level0 col8" >Val Accuracy</th>
#       <th id="T_7e193_level0_col9" class="col_heading level0 col9" >Val Balanced Acc</th>
#       <th id="T_7e193_level0_col10" class="col_heading level0 col10" >Val Macro-F1</th>
#       <th id="T_7e193_level0_col11" class="col_heading level0 col11" >Test Accuracy</th>
#       <th id="T_7e193_level0_col12" class="col_heading level0 col12" >Test Balanced Acc</th>
#       <th id="T_7e193_level0_col13" class="col_heading level0 col13" >Test Macro-F1</th>
#       <th id="T_7e193_level0_col14" class="col_heading level0 col14" >Tiempo (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e193_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e193_row0_col0" class="data row0 col0" >ARCH 127</td>
#       <td id="T_7e193_row0_col1" class="data row0 col1" >CNN</td>
#       <td id="T_7e193_row0_col2" class="data row0 col2" >105,162</td>
#       <td id="T_7e193_row0_col3" class="data row0 col3" >[32, 64, 128]</td>
#       <td id="T_7e193_row0_col4" class="data row0 col4" >[]</td>
#       <td id="T_7e193_row0_col5" class="data row0 col5" >True</td>
#       <td id="T_7e193_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_7e193_row0_col7" class="data row0 col7" >True</td>
#       <td id="T_7e193_row0_col8" class="data row0 col8" >0.991379</td>
#       <td id="T_7e193_row0_col9" class="data row0 col9" >0.992500</td>
#       <td id="T_7e193_row0_col10" class="data row0 col10" >98.95%</td>
#       <td id="T_7e193_row0_col11" class="data row0 col11" >0.983000</td>
#       <td id="T_7e193_row0_col12" class="data row0 col12" >0.982897</td>
#       <td id="T_7e193_row0_col13" class="data row0 col13" >98.29%</td>
#       <td id="T_7e193_row0_col14" class="data row0 col14" >32.1</td>
#     </tr>
#     <tr>
#       <th id="T_7e193_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e193_row1_col0" class="data row1 col0" >ARCH 082</td>
#       <td id="T_7e193_row1_col1" class="data row1 col1" >CNN</td>
#       <td id="T_7e193_row1_col2" class="data row1 col2" >104,650</td>
#       <td id="T_7e193_row1_col3" class="data row1 col3" >[32, 64, 128]</td>
#       <td id="T_7e193_row1_col4" class="data row1 col4" >[]</td>
#       <td id="T_7e193_row1_col5" class="data row1 col5" >True</td>
#       <td id="T_7e193_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_7e193_row1_col7" class="data row1 col7" >True</td>
#       <td id="T_7e193_row1_col8" class="data row1 col8" >0.991379</td>
#       <td id="T_7e193_row1_col9" class="data row1 col9" >0.996250</td>
#       <td id="T_7e193_row1_col10" class="data row1 col10" >99.32%</td>
#       <td id="T_7e193_row1_col11" class="data row1 col11" >0.979600</td>
#       <td id="T_7e193_row1_col12" class="data row1 col12" >0.979359</td>
#       <td id="T_7e193_row1_col13" class="data row1 col13" >97.95%</td>
#       <td id="T_7e193_row1_col14" class="data row1 col14" >25.7</td>
#     </tr>
#     <tr>
#       <th id="T_7e193_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e193_row2_col0" class="data row2 col0" >ARCH 032</td>
#       <td id="T_7e193_row2_col1" class="data row2 col1" >CNN</td>
#       <td id="T_7e193_row2_col2" class="data row2 col2" >214,634</td>
#       <td id="T_7e193_row2_col3" class="data row2 col3" >[16, 32]</td>
#       <td id="T_7e193_row2_col4" class="data row2 col4" >[128, 64]</td>
#       <td id="T_7e193_row2_col5" class="data row2 col5" >True</td>
#       <td id="T_7e193_row2_col6" class="data row2 col6" >False</td>
#       <td id="T_7e193_row2_col7" class="data row2 col7" >True</td>
#       <td id="T_7e193_row2_col8" class="data row2 col8" >0.982759</td>
#       <td id="T_7e193_row2_col9" class="data row2 col9" >0.980000</td>
#       <td id="T_7e193_row2_col10" class="data row2 col10" >97.30%</td>
#       <td id="T_7e193_row2_col11" class="data row2 col11" >0.977000</td>
#       <td id="T_7e193_row2_col12" class="data row2 col12" >0.976639</td>
#       <td id="T_7e193_row2_col13" class="data row2 col13" >97.69%</td>
#       <td id="T_7e193_row2_col14" class="data row2 col14" >30.8</td>
#     </tr>
#     <tr>
#       <th id="T_7e193_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e193_row3_col0" class="data row3 col0" >ARCH 157</td>
#       <td id="T_7e193_row3_col1" class="data row3 col1" >CNN</td>
#       <td id="T_7e193_row3_col2" class="data row3 col2" >250,122</td>
#       <td id="T_7e193_row3_col3" class="data row3 col3" >[32, 64, 128]</td>
#       <td id="T_7e193_row3_col4" class="data row3 col4" >[128, 64]</td>
#       <td id="T_7e193_row3_col5" class="data row3 col5" >True</td>
#       <td id="T_7e193_row3_col6" class="data row3 col6" >False</td>
#       <td id="T_7e193_row3_col7" class="data row3 col7" >True</td>
#       <td id="T_7e193_row3_col8" class="data row3 col8" >0.986207</td>
#       <td id="T_7e193_row3_col9" class="data row3 col9" >0.985625</td>
#       <td id="T_7e193_row3_col10" class="data row3 col10" >98.40%</td>
#       <td id="T_7e193_row3_col11" class="data row3 col11" >0.972200</td>
#       <td id="T_7e193_row3_col12" class="data row3 col12" >0.972318</td>
#       <td id="T_7e193_row3_col13" class="data row3 col13" >97.20%</td>
#       <td id="T_7e193_row3_col14" class="data row3 col14" >24.9</td>
#     </tr>
#     <tr>
#       <th id="T_7e193_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e193_row4_col0" class="data row4 col0" >ARCH 124</td>
#       <td id="T_7e193_row4_col1" class="data row4 col1" >CNN</td>
#       <td id="T_7e193_row4_col2" class="data row4 col2" >105,162</td>
#       <td id="T_7e193_row4_col3" class="data row4 col3" >[32, 64, 128]</td>
#       <td id="T_7e193_row4_col4" class="data row4 col4" >[]</td>
#       <td id="T_7e193_row4_col5" class="data row4 col5" >True</td>
#       <td id="T_7e193_row4_col6" class="data row4 col6" >True</td>
#       <td id="T_7e193_row4_col7" class="data row4 col7" >False</td>
#       <td id="T_7e193_row4_col8" class="data row4 col8" >0.987931</td>
#       <td id="T_7e193_row4_col9" class="data row4 col9" >0.994375</td>
#       <td id="T_7e193_row4_col10" class="data row4 col10" >98.98%</td>
#       <td id="T_7e193_row4_col11" class="data row4 col11" >0.970700</td>
#       <td id="T_7e193_row4_col12" class="data row4 col12" >0.970538</td>
#       <td id="T_7e193_row4_col13" class="data row4 col13" >97.08%</td>
#       <td id="T_7e193_row4_col14" class="data row4 col14" >18.2</td>
#     </tr>
#   </tbody>
# </table>

# %%
metric_cols = ["Test Accuracy", "Test Balanced Acc", "Test Macro-F1"]
plot_df = results_df.copy()

fig, ax = plt.subplots(figsize=(12, 5))
x = np.arange(len(plot_df))
width = 0.24

for i, metric in enumerate(metric_cols):
    ax.bar(x + (i - 1) * width, plot_df[metric], width=width, edgecolor="black", label=metric)

ax.set_xticks(x)
ax.set_xticklabels(plot_df["Experimento"], rotation=15, ha="right")
ax.set_ylim(0.75, 1.0)
ax.set_ylabel("Valor de la métrica")
ax.set_title("Comparación de métricas globales sobre el conjunto de test")
ax.legend()
plt.tight_layout()
plt.show()

# %%
metric_pairs = [
    ("train_loss", "val_loss", "Pérdida"),
    ("train_macro_f1", "val_macro_f1", "Macro-F1"),
]
plot_histories_grid(histories_final, metric_pairs=metric_pairs)

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 13))
axes = axes.flatten()

for ax, exp in zip(axes, best_experiments_arch[1:]):
    name = exp["name"]
    preds = trained_models_final[name]["test_preds"]
    true = trained_models_final[name]["test_true"]

    cm = confusion_matrix(true, preds, normalize="true")
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(range(10)))
    disp.plot(ax=ax, cmap="Blues", colorbar=False, values_format=".2f")
    ax.set_title(name.replace("_", " "), fontsize=13, fontweight="bold")
    ax.grid(False)

fig.suptitle("Matrices de confusión normalizadas sobre test", fontsize=16, fontweight="bold", y=0.99)
plt.tight_layout()
plt.show()

# %%
for exp in best_experiments_arch:
    name = exp["name"]
    print(f"\n{name}")
    for i, j, n in top_confusions(trained_models_final[name]["test_true"], trained_models_final[name]["test_preds"], top_k=5):
        print(f"  Clase real {i} → predicha como {j}: {n} veces")
# Out:
# ARCH_032
#   Clase real 9 → predicha como 7: 26 veces
#   Clase real 4 → predicha como 9: 20 veces
#   Clase real 5 → predicha como 3: 18 veces
#   Clase real 9 → predicha como 3: 18 veces
#   Clase real 7 → predicha como 2: 14 veces
#
# ARCH_082
#   Clase real 4 → predicha como 9: 26 veces
#   Clase real 6 → predicha como 0: 11 veces
#   Clase real 8 → predicha como 4: 11 veces
#   Clase real 7 → predicha como 2: 10 veces
#   Clase real 8 → predicha como 9: 10 veces
#
# ARCH_124
#   Clase real 9 → predicha como 4: 31 veces
#   Clase real 9 → predicha como 7: 27 veces
#   Clase real 8 → predicha como 4: 20 veces
#   Clase real 2 → predicha como 0: 16 veces
#   Clase real 8 → predicha como 0: 16 veces
#
# ARCH_127
#   Clase real 4 → predicha como 9: 15 veces
#   Clase real 9 → predicha como 4: 15 veces
#   Clase real 7 → predicha como 2: 13 veces
#   Clase real 9 → predicha como 7: 10 veces
#   Clase real 7 → predicha como 9: 8 veces
#
# ARCH_157
#   Clase real 7 → predicha como 2: 70 veces
#   Clase real 9 → predicha como 8: 26 veces
#   Clase real 8 → predicha como 6: 19 veces
#   Clase real 3 → predicha como 5: 15 veces
#   Clase real 9 → predicha como 4: 14 veces

# %% [markdown]
# ## 19. Errores frecuentes de interpretación
#
# - **“La accuracy es alta, entonces el modelo está bien.”**
#   Falso: puede estar ignorando clases minoritarias.
#
# - **“La CNN gana sólo porque tiene más parámetros.”**
#   Incompleto: también gana por su sesgo inductivo.
#
# - **“Si la train loss es mayor que la val loss, hay un bug.”**
#   No necesariamente: con augmentation y dropout el train puede ser más difícil.
#
# - **“Regularización siempre mejora todo al mismo tiempo.”**
#   No: a veces sacrifica algo de accuracy global para mejorar clases difíciles.
#
# - **“Más complejidad siempre da mejor generalización.”**
#   No: depende del tamaño del dataset, del problema y de la arquitectura.

# %% [markdown]
# ## 20. Conclusión
#
# Este trabajo práctico muestra que un problema aparentemente “simple” como MNIST puede transformarse en una excelente plataforma para estudiar ideas profundas de aprendizaje profundo si cambiamos el régimen de datos.
#
# Al reducir drásticamente el conjunto de entrenamiento y desbalancear las clases, aparecen de manera visible:
#
# - el overfitting;
# - la importancia del sesgo inductivo;
# - el papel de la regularización;
# - la necesidad de usar métricas adecuadas;
# - y el valor de analizar cómo se equivoca un modelo, no sólo cuánto acierta.
#
# ### Cierre
# La lección central no es que “las CNN ganan a las MLP”.
#
# La lección central es que **arquitectura, datos, regularización y métrica forman un sistema**. Entender ese sistema es una parte esencial de aprender Deep Learning.

# %% [markdown]
# ## 21. Entregables sugeridos
#
# Para la entrega, se espera que cada grupo incluya:
#
# 1. las arquitecturas implementadas;
# 2. el loop de entrenamiento completo;
# 3. tablas y gráficos finales;
# 4. una discusión conceptual breve respondiendo:
#    - qué modelo generalizó mejor;
#    - qué efecto tuvo la regularización;
#    - qué métrica resultó más informativa;
#    - qué clases fueron más difíciles y por qué.
#
# Podés agregar variantes propias, pero asegurate de conservar la comparación base entre **MLP** y **CNN**.

# %%
best_model = trained_models_final['ARCH_127']['model']
torch.save(best_model.state_dict(), 'best_model_gomez.pth')

# %%
model = SimpleCNN([32, 64, 128], [5, 3, 3], [2, 1, 1], hidden_layers=[], dropout=0.25, batch_norm=True) 
model.load_state_dict(torch.load('best_model_gomez.pth'))
# Out:
# <All keys matched successfully>
